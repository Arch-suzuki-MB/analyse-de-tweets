# %%
pip install inflect
# Out:
# Collecting inflect
#   Downloading inflect-5.6.0-py3-none-any.whl (33 kB)
# Installing collected packages: inflect
# Successfully installed inflect-5.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\safae\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: joblib in c:\users\safae\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: click in c:\users\safae\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\safae\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\safae\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.3.15)
# Requirement already satisfied: colorama in c:\users\safae\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install elasticsearch==7.0.0
# Out:
# Collecting elasticsearch==7.0.0
#   Downloading elasticsearch-7.0.0-py2.py3-none-any.whl (80 kB)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\safae\anaconda3\lib\site-packages (from elasticsearch==7.0.0) (1.26.9)
# Installing collected packages: elasticsearch
# Successfully installed elasticsearch-7.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kafka-python
# Out:
# Collecting kafka-pythonNote: you may need to restart the kernel to use updated packages.
#   Using cached kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
import time
import inflect
import re
import string
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.corpus import stopwords # used for preprocessing
from nltk.stem import WordNetLemmatizer # used for preprocessing
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from operator import add
from kafka import KafkaConsumer
import json
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\safae\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\safae\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\safae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from elasticsearch import Elasticsearch
# create instance of elasticsearch
es = Elasticsearch([{'host':'localhost','port':9200}])

# %%
es.ping()
# Out:
# True

# %%
topic_name = 'test'
# ------------------- your consummer ------------------- -----
consumer = KafkaConsumer(
    topic_name,
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='latest',
     enable_auto_commit=True,
     auto_commit_interval_ms =  5000,
     fetch_max_bytes = 128,
     max_poll_records = 100,
     )

# %%
#-------------------Traitement du data -----------------------

def remove_urls(text):
    new_text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^A-Za-z# \t])|(\w+:\/\/\S+)"," ",text).split())
    return new_text

# make all text lowercase
def text_lowercase(text):
    return text.lower()

# make all text Uppercase

def text_uppercase(text):
    return text.upper()

# %%
#----------delete numbers from text ---------

def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result

# %%
# --------------- delete ponctuation existent on text ----------

def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)


# ----------------convert list to words ---------------
def tokenize(text):
    text = word_tokenize(text)
    return text

# %%
#----------- delete words non significant ---------
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    text = [i for i in text if not i in stop_words]
    return text

# %%
# ---------------get the origins of words--------------
lemmatizer = WordNetLemmatizer()
def lemmatize(text):
    text = [lemmatizer.lemmatize(token) for token in text]
    return text

# %%
# -------------remplace all number with word notation-----------
def numbers_to_char(text):
    wordtoken = nltk.word_tokenize(text)
    p = inflect.engine()
    new_Text = []
    for word in wordtoken:
        if word.isdigit():
            newword = p.number_to_words(word)
            new_Text.append(newword)
        else:
            new_Text.append(word)
    return new_Text

# %%
#--------------------------end analyse feedback using textBlob--------------------------------
def analyze_sentiment(text):
    testimonial = TextBlob(text)
    return testimonial.sentiment.polarity
def get_sentiment_tuple(sent):
    neutral_threshold = 0.05
    if sent >= neutral_threshold:       # positive
        return (0, 0, 1),"positive"
    elif sent > -neutral_threshold:     # neutral
        return (0, 1, 0),"neutral"
    else:                               # negative
        return (1, 0, 0),"negative"

# %%
counter=0 
def topHashtag(text):
    return text.split(" ")
def getNouns(txt):
    blob = TextBlob(txt)
    print(blob.noun_phrases)

# %%
for msg in consumer:
        #print(str(1));
        time.sleep(2)
      
        data= text_lowercase(msg.value)
        
        
        #------hashtages----------------------------------------------
        dict_data=json.loads(data)
        key="text"
        if (key in dict_data.keys()):
            print(dict_data["text"])
            hashtags = re.findall("#[a-zA-Z0-9_]{1,200}", dict_data["text"])
            print("hashtags :",hashtags)
       
        #---feedback-----------------------------------
            tweets=TextBlob(dict_data["text"])
            sentiments=analyze_sentiment(dict_data["text"])

        #----------best and bad tweets ------------------
            frequencetweets= text_lowercase(dict_data["text"])
            frequencetweets=remove_urls(frequencetweets)

        #----------- frequency of words---------------
            filtreData= text_lowercase(dict_data["text"])
            filtredData=remove_urls(filtreData)
            filtredData=remove_punctuation(filtredData)
            filtredData=tokenize(filtredData)
            filtredData=remove_stopwords(filtredData)
            FrequencesMots=lemmatize(filtredData)
  
            print(FrequencesMots)
            analysentimens,feedback=get_sentiment_tuple(sentiments)
            print("val :",analysentimens,"  sentiments : ",feedback)
       
        # ------------------- send all result to elastic search --------------------- 
            
            es.index(index="tweet_index" ,
                    doc_type="test_doc",
                    body={
                            "author": dict_data["user"]["screen_name"],
                            "date": dict_data["created_at"],
                            "message": dict_data["text"], 
                            "sentimentsPer":sentiments,
                            "feedback":feedback,
                            "hashtag":hashtags,
                            "FrequencMots":FrequencesMots,
                            "FrequenceTweets":frequencetweets
                    }
                )
           
             
        #-------------------------- optional ---------------------
        #time.sleep(5)
        #print(str(tweets))
        print('\n')
# Out:
# rt @the_jordanc: it’s been a tough first day without seniors at wb cte… we just can’t hold back. @wbhsgovernors @wbgovscte https://t.co/bge…
# hashtags : []
# ['rt', 'jordanc', 'tough', 'first', 'day', 'without', 'senior', 'wb', 'cte', 'hold', 'back']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @versuhtyle i'm pretty sure the financial hit will be enough of a lesson, not sure how piling on would help. you ca… https://t.co/ubod9dhxmt
# hashtags : []
# ['pretty', 'sure', 'financial', 'hit', 'enough', 'lesson', 'sure', 'piling', 'would', 'help', 'ca']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @susanboorh @teekaydawn @angenette5 @lawcrimenetwork @lawcrimenews that's what i was wondering.  what's barkin got to do with any of this?
# hashtags : []
# ['wondering', 'barkin', 'got']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @centuriic i started playing this game..🥹
# i love many elden ring girls and milfs 😳👉👈
# hashtags : []
# ['started', 'playing', 'game', 'love', 'many', 'elden', 'ring', 'girl', 'milfs']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @sarah_w_kata @ewwababewwa so i'll just have english and dutch
# hashtags : []
# ['w', 'kata', 'english', 'dutch']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ledbettercarly: update: archewell has partnered with the national business coalition for child care, which is organized by the marshall…
# hashtags : []
# ['rt', 'update', 'archewell', 'partnered', 'national', 'business', 'coalition', 'child', 'care', 'organized', 'marshall']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @tearaminty1: omg! i'm so addicted for listening the best ost #withyou by #jimin #btsjimin of #bts (@bts_twt) and sungwoon. please keep…
# hashtags : ['#withyou', '#jimin', '#btsjimin', '#bts']
# ['rt', 'omg', 'addicted', 'listening', 'best', 'ost', 'withyou', 'jimin', 'btsjimin', 'bts', 'twt', 'sungwoon', 'please', 'keep']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @crysusius @conservblue2020 @potus yes, a pandemic that he mishandled. if he cut out the pandemic early, then 1,000… https://t.co/min8yyt2ps
# hashtags : []
# ['yes', 'pandemic', 'mishandled', 'cut', 'pandemic', 'early']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @abc: the u.s. interior department is expected to release a report that it says will begin to uncover the truth about the federal govern…
# hashtags : []
# ['rt', 'u', 'interior', 'department', 'expected', 'release', 'report', 'say', 'begin', 'uncover', 'truth', 'federal', 'govern']
# val : (1, 0, 0)   sentiments :  negative
#
#
# 『swimmer to a liquid armchair』ricked wicky #聴いている https://t.co/lum3z3culh
# hashtags : []
# ['swimmer', 'liquid', 'armchair', 'ricked', 'wicky']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i hope today’s too the world be kinder to you, take care of your health and let your plate fill with dishes that co… https://t.co/bci5pebai1
# hashtags : []
# ['hope', 'today', 'world', 'kinder', 'take', 'care', 'health', 'let', 'plate', 'fill', 'dish', 'co']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# the biggest adjustment while working at home was when my husband started working at home as well.
# hashtags : []
# ['biggest', 'adjustment', 'working', 'home', 'husband', 'started', 'working', 'home', 'well']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @trollntrhaterz: wishing @urstrulymahesh anna &amp; the entire team of #svp a huge success..best wishes from @tarak9999 fans ❤️ https://t.co…
# hashtags : ['#svp']
# ['rt', 'wishing', 'anna', 'amp', 'entire', 'team', 'svp', 'huge', 'success', 'best', 'wish', 'fan']
# val : (0, 0, 1)   sentiments :  positive
#
#
# d1994c8c :battle id
# i need backup!
# lvl 120 grimnir
# https://t.co/fvqpo8tuc0
# hashtags : []
# ['c', 'c', 'battle', 'id', 'need', 'backup', 'lvl', 'grimnir']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# for the first time i want to be reezal merican for just one hour lol
# #tuc2022 #thomasubercup2022
# hashtags : ['#tuc2022', '#thomasubercup2022']
# ['first', 'time', 'want', 'reezal', 'merican', 'one', 'hour', 'lol', 'tuc', 'thomasubercup']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @eliowa: i’m guessing it’s because many were:
#
# privileged living in masking cities
# privileged to be vaccinated/boosted
# privileged to pu…
# hashtags : []
# ['rt', 'guessing', 'many', 'privileged', 'living', 'masking', 'city', 'privileged', 'vaccinated', 'boosted', 'privileged', 'pu']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @eshaeyyy: why would he love me?
# when i’m not even pretty
# hashtags : []
# ['rt', 'would', 'love', 'even', 'pretty']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @happyvirusisj that account made up stories as if j is a villain and her bias is a saint
# hashtags : []
# ['account', 'made', 'story', 'j', 'villain', 'bias', 'saint']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ksgupdates: 220511 🐻💬
#
# "right now i'm on my way home so even if you find me, you couldn't find me.. ah.. ㅋㅋ"
# "you say i'm a legendary p…
# hashtags : []
# ['rt', 'right', 'way', 'home', 'even', 'find', 'find', 'ah', 'say', 'legendary', 'p']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @soranonft @s_ferlia do you guys have any other place i can learn more}?
# hashtags : []
# ['ferlia', 'guy', 'place', 'learn']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @moazzam_begg: i’ve recently been speaking to abdul latif (morocco, 2021) and sufiyan (algeria, 2022) both freed from #guantanamo after…
# hashtags : ['#guantanamo']
# ['rt', 'begg', 'recently', 'speaking', 'abdul', 'latif', 'morocco', 'sufiyan', 'algeria', 'freed', 'guantanamo']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @allthesinglega1: the back of the bus dared him to go naked and he punished us by showing his asshole. i didn’t know the feeling of domi…
# hashtags : []
# ['rt', 'back', 'bus', 'dared', 'go', 'naked', 'punished', 'u', 'showing', 'asshole', 'know', 'feeling', 'domi']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @anthraxedamame: whys there a biblically accurate angel on my porch https://t.co/7yz2wyron5
# hashtags : []
# ['rt', 'why', 'biblically', 'accurate', 'angel', 'porch']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @thebradfordfile: ukraine is a money laundering scam for the ruling class.
# hashtags : []
# ['rt', 'ukraine', 'money', 'laundering', 'scam', 'ruling', 'class']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @moleonfoot: pink business 2
# per your input guys...keep em coming, i'll consolidate
#
# wildbreads
# kapesur
# https://t.co/2g3osl5x2w
# tinda ti…
# hashtags : []
# ['rt', 'pink', 'business', 'per', 'input', 'guy', 'keep', 'em', 'coming', 'consolidate', 'wildbreads', 'kapesur', 'tinda', 'ti']
# val : (1, 0, 0)   sentiments :  negative
#
#
# i had discovered that there was somethin https://t.co/xc3l4rycnf
# hashtags : []
# ['discovered', 'somethin']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @capybara_man: capybara snuggling with a cat https://t.co/qyyvcl6rfb
# hashtags : []
# ['rt', 'man', 'capybara', 'snuggling', 'cat']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i had discovered that there was somethin https://t.co/go5wuvnzy8
# hashtags : []
# ['discovered', 'somethin']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @noliewithbtc: new: marsha blackburn (r-tn) just said that peaceful demonstrators protesting against the supreme court overturning roe v…
# hashtags : []
# ['rt', 'new', 'marsha', 'blackburn', 'r', 'tn', 'said', 'peaceful', 'demonstrator', 'protesting', 'supreme', 'court', 'overturning', 'roe', 'v']
# val : (0, 0, 1)   sentiments :  positive
#
#
# following the local election i am resuming my councillor's advice session on saturday 14th may, 2022 between 1-2pm… https://t.co/nntq395n6b
# hashtags : []
# ['following', 'local', 'election', 'resuming', 'councillor', 'advice', 'session', 'saturday', 'th', 'may', 'pm']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @xxjisoyaaa @kenthoughtss @bsilonga i never justified toxicity and negative campaigning. i dislike bbm as well. i'm… https://t.co/ys8397c1ds
# hashtags : []
# ['never', 'justified', 'toxicity', 'negative', 'campaigning', 'dislike', 'bbm', 'well']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @d_t0m_: preview (?) of a mini comic im trying to finish #huntlow #huntertoh #willowtoh #theowlhouse https://t.co/knzgwg27va
# hashtags : ['#huntlow', '#huntertoh', '#willowtoh', '#theowlhouse']
# ['rt', 'preview', 'mini', 'comic', 'im', 'trying', 'finish', 'huntlow', 'huntertoh', 'willowtoh', 'theowlhouse']
# val : (0, 0, 1)   sentiments :  positive
# rt @nooranhamdan: she died reporting. telling the truth. making the palestinian story heard, as she has for years. a martyr in every sense…
# hashtags : []
# ['rt', 'died', 'reporting', 'telling', 'truth', 'making', 'palestinian', 'story', 'heard', 'year', 'martyr', 'every', 'sense']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# “as if killing her in the morning was not enough, israeli security had to raid her house in the afternoon.”
# hashtags : []
# ['killing', 'morning', 'enough', 'israeli', 'security', 'raid', 'house', 'afternoon']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @spaceastrobtc @asunahentai_bsc i will try to update with &amp; never miss any news.
# hashtags : []
# ['bsc', 'try', 'update', 'amp', 'never', 'miss', 'news']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @keeleyfox29: the @phillypolice crime scene unit now at crime scene inside 39th philadelphia police district offices.   man with knife s…
# hashtags : []
# ['rt', 'crime', 'scene', 'unit', 'crime', 'scene', 'inside', 'th', 'philadelphia', 'police', 'district', 'office', 'man', 'knife']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @angie_rasmussen: lab leak twitter is, as usual, just asking for an investigation of both natural and lab origin hypotheses.
#
# my coautho…
# hashtags : []
# ['rt', 'rasmussen', 'lab', 'leak', 'twitter', 'usual', 'asking', 'investigation', 'natural', 'lab', 'origin', 'hypothesis', 'coautho']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @deeptxtmsgs: i’m so sensitive i swear everything breaks my heart.
# hashtags : []
# ['rt', 'sensitive', 'swear', 'everything', 'break', 'heart']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @idalsocix: cix first usa tour is over and i’m so thankful for the boys and how hard they’ve worked despite their jam packed schedule. t…
# hashtags : []
# ['rt', 'cix', 'first', 'usa', 'tour', 'thankful', 'boy', 'hard', 'worked', 'despite', 'jam', 'packed', 'schedule']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @tianaamonet: i’ll 🫶🏽🫶🏽🫶🏽🫶🏽🫶🏽🫶🏽🫶🏽🫶🏽🫶🏽🫶🏽 somebody to death i love that emoji lol
# hashtags : []
# ['rt', 'somebody', 'death', 'love', 'emoji', 'lol']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @jen4ssr: sushant 4 women empowerment
#
# promoting women entrepreneurship is the need of the hour. women contribute significantly to gdp.…
# hashtags : []
# ['rt', 'sushant', 'woman', 'empowerment', 'promoting', 'woman', 'entrepreneurship', 'need', 'hour', 'woman', 'contribute', 'significantly', 'gdp']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i’m sure they got enough recorded but just thinking that now we will probably never get a young thug and gunna albu… https://t.co/gf8etryt68
# hashtags : []
# ['sure', 'got', 'enough', 'recorded', 'thinking', 'probably', 'never', 'get', 'young', 'thug', 'gunna', 'albu']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @amyklobuchar: today, the senate votes on codifying roe into law. it shouldn’t even be a question.
# hashtags : []
# ['rt', 'today', 'senate', 'vote', 'codifying', 'roe', 'law', 'even', 'question']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# lol everyone gets one these days
# hashtags : []
# ['lol', 'everyone', 'get', 'one', 'day']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @lynzforcongress: but hartzler’s connection with the authoritarian orbán regime don’t end with a visit to her office. she’s also spoken…
# hashtags : []
# ['rt', 'hartzler', 'connection', 'authoritarian', 'orb', 'n', 'regime', 'end', 'visit', 'office', 'also', 'spoken']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i ❤️ rock 🙋🏻‍♂️😎🤟🏼 https://t.co/lsnu3iyblz
# hashtags : []
# ['rock']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @repthomasmassie: counting last night’s rushed vote, congress has now spent more money on ukraine in six months than we spend on all us…
# hashtags : []
# ['rt', 'counting', 'last', 'night', 'rushed', 'vote', 'congress', 'spent', 'money', 'ukraine', 'six', 'month', 'spend', 'u']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @rahelyoseif: |'we ought to have buried him alive' one other man mentioned. one man fingers a small lady a rock to throw on the boy’s he…
# hashtags : []
# ['rt', 'ought', 'buried', 'alive', 'one', 'man', 'mentioned', 'one', 'man', 'finger', 'small', 'lady', 'rock', 'throw', 'boy']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @__sunshinelou__ i hate harry styles
# hashtags : []
# ['sunshinelou', 'hate', 'harry', 'style']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @oohyeolie i thought it's milkshake's twt for a sec 😭😭
# hashtags : []
# ['thought', 'milkshake', 'twt', 'sec']
# val : (1, 0, 0)   sentiments :  negative
#
#
#
#
# rt @premierscottmoe: i look forward to strengthening our province’s relationship with the uae and to deliver the keynote speech at global p…
# hashtags : []
# ['rt', 'look', 'forward', 'strengthening', 'province', 'relationship', 'uae', 'deliver', 'keynote', 'speech', 'global', 'p']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i thought it was sunoo
# hashtags : []
# ['thought', 'sunoo']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @john_sipher: they are like the silicon valley of murder and mayhem.
# hashtags : []
# ['rt', 'sipher', 'like', 'silicon', 'valley', 'murder', 'mayhem']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @del_tekam: woww 🥳🥳 wait is over tight anus realistic male ass 😵‍💫
#
# the horny hole made me cum like a faucet 😛
#
# -3d real channel with g…
# hashtags : []
# ['rt', 'tekam', 'woww', 'wait', 'tight', 'anus', 'realistic', 'male', 'as', 'horny', 'hole', 'made', 'cum', 'like', 'faucet', 'real', 'channel', 'g']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# the logic that i come up with as to why i spend so much money on clothes is truly sick 😭
# hashtags : []
# ['logic', 'come', 'spend', 'much', 'money', 'clothes', 'truly', 'sick']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @yourswgirl_m ughhh i need this
# hashtags : []
# ['ughhh', 'need']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# this year's theme for mental health awareness week is loneliness. the impact of covid-19 has been significant on ev… https://t.co/f4zg122n8k
# hashtags : []
# ['year', 'theme', 'mental', 'health', 'awareness', 'week', 'loneliness', 'impact', 'covid', 'significant', 'ev']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @itssstiaa: i can care about you &amp; still cut you off &amp; i can miss you &amp; never talk to you again.
# hashtags : []
# ['rt', 'care', 'amp', 'still', 'cut', 'amp', 'miss', 'amp', 'never', 'talk']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @polydepression: this intro got me hollering lmao
#
# ea put their best work into a golf game https://t.co/r4wnonkvss
# hashtags : []
# ['rt', 'intro', 'got', 'hollering', 'lmao', 'ea', 'put', 'best', 'work', 'golf', 'game']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @adaobiwude1: idara gold was illegally abducted by the @nigeriadss because "she wore the wrong colors" of a cloth during her birthday.…
# hashtags : []
# ['rt', 'idara', 'gold', 'illegally', 'abducted', 'wore', 'wrong', 'color', 'cloth', 'birthday']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @ign: the price of a nintendo switch has dropped in the us. https://t.co/rtr89ufbcx https://t.co/y378vd8tce
# hashtags : []
# ['rt', 'price', 'nintendo', 'switch', 'dropped', 'u']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @elisaba62356413 @frosso747 @dazz_unusual @ytwonderlady @lindseyboylan this is the type of bs amber supporters spew… https://t.co/f1w464fswc
# hashtags : []
# ['unusual', 'type', 'b', 'amber', 'supporter', 'spew']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @kathy4truth: i need everyone to share this video.
#
# we are just days away from making history.
#
# someone tell joe biden that kathy barnet…
# hashtags : []
# ['rt', 'need', 'everyone', 'share', 'video', 'day', 'away', 'making', 'history', 'someone', 'tell', 'joe', 'biden', 'kathy', 'barnet']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @keggs719 i bet you make maga hats also.
# hashtags : []
# ['bet', 'make', 'maga', 'hat', 'also']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @tedlassod @lisa_bocchetti @bobbymcnally2 @peterschiff @joebiden because it’s not possible that a person of color is the best candidate?
# hashtags : []
# ['bocchetti', 'possible', 'person', 'color', 'best', 'candidate']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i am really happy that @thenotoriousmma dealth with the concern earlier on. i am glad and happy for him that he cau… https://t.co/csnrcy9ask
# hashtags : []
# ['really', 'happy', 'dealth', 'concern', 'earlier', 'glad', 'happy', 'cau']
# val : (0, 0, 1)   sentiments :  positive
# @christophclarey tbh, i think rafa is pissed, how about let carlos win a slam and get to no 1 first, and do it cons… https://t.co/zoao7f991v
# hashtags : []
# ['tbh', 'think', 'rafa', 'pissed', 'let', 'carlos', 'win', 'slam', 'get', 'first', 'con']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @char_x0: i can understand why chickens wake up and scream
# hashtags : []
# ['rt', 'x', 'understand', 'chicken', 'wake', 'scream']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @dataasu: @ojumpy_ @3str3am just get a job you fucking mong you can’t live with your parents forever and sell cameos nobody knows how to…
# hashtags : []
# ['rt', 'get', 'job', 'fucking', 'mong', 'live', 'parent', 'forever', 'sell', 'cameo', 'nobody', 'know']
# val : (1, 0, 0)   sentiments :  negative
#
#
# is your clout missing stupid animal
# hashtags : []
# ['clout', 'missing', 'stupid', 'animal']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @newsjisoo: i vote #jisoo for #destaquesérieasiática and i vote #snowdrop for #sérieasiática at the #secawards 2022
#
#  https://t.co/doadg…
# hashtags : ['#jisoo', '#destaques', '#snowdrop', '#s', '#secawards']
# ['rt', 'vote', 'jisoo', 'destaques', 'rieasi', 'tica', 'vote', 'snowdrop', 'rieasi', 'tica', 'secawards']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @thethafm_1006: breaking news
# houses are currently being demolished in beverly hills , vaal. it is alleged that the houses were built o…
# hashtags : []
# ['rt', 'breaking', 'news', 'house', 'currently', 'demolished', 'beverly', 'hill', 'vaal', 'alleged', 'house', 'built']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @sanasaeed: shireen abu akleh isn’t just an al jazeera journalist, she’s also a palestinian, born in jerusalem. she was killed by the ve…
# hashtags : []
# ['rt', 'shireen', 'abu', 'akleh', 'al', 'jazeera', 'journalist', 'also', 'palestinian', 'born', 'jerusalem', 'killed']
# val : (1, 0, 0)   sentiments :  negative
#
#
# my point exactly. a brilliant answer.
# hashtags : []
# ['point', 'exactly', 'brilliant', 'answer']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @volcelgf umbmmm.. i simply just love you!!! i love u thank uuuu &lt;3_&lt;3
# hashtags : []
# ['umbmmm', 'simply', 'love', 'love', 'u', 'thank', 'uuuu', 'lt', 'lt']
# val : (0, 0, 1)   sentiments :  positive
#
#
# we can argue, we can fight but i’ll never switch up on my people
# hashtags : []
# ['argue', 'fight', 'never', 'switch', 'people']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# nero burning room
# circa a.d. 64, *colourised* https://t.co/revi4mj3zb
# hashtags : []
# ['nero', 'burning', 'room', 'circa', 'colourised']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @sssyringaaa it's bad for me i fear https://t.co/9k0csbjjfw
# hashtags : []
# ['bad', 'fear']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @lalala_havefwm: (day-2)
# hi i'm yena i'm looking for interactive moots, any fandom will do, rt this post to spread my papansin momints e…
# hashtags : []
# ['rt', 'havefwm', 'day', 'hi', 'yena', 'looking', 'interactive', 'moot', 'fandom', 'rt', 'post', 'spread', 'papansin', 'momints', 'e']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @angelicaagelviz: more still shots from the #spongebobsquarepants special! i really wanted to respect the beauty of the original shots b…
# hashtags : ['#spongebobsquarepants']
# ['rt', 'still', 'shot', 'spongebobsquarepants', 'special', 'really', 'wanted', 'respect', 'beauty', 'original', 'shot', 'b']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @warby1kenobi: selling off channel 4, a profit-making publicly-owned asset, makes no sense. this puts jobs, small businesses and popular…
# hashtags : []
# ['rt', 'selling', 'channel', 'profit', 'making', 'publicly', 'owned', 'asset', 'make', 'sense', 'put', 'job', 'small', 'business', 'popular']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @shinpath @chris__pc @peterzeihan which camp should i "go away" to, sir? i am not sure how to measure the chinese m… https://t.co/myuojiu893
# hashtags : []
# ['pc', 'camp', 'go', 'away', 'sir', 'sure', 'measure', 'chinese']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @bkowal23 @fivewithflores honestly, it’s be kind of nice to have a format for a minute that isn’t just “all your sp… https://t.co/xswjszjj94
# hashtags : []
# ['honestly', 'kind', 'nice', 'format', 'minute', 'sp']
# val : (0, 0, 1)   sentiments :  positive
#
#
# chairman !️ of the verkhovna rada of ukraine ruslan stefanchuk during a meeting with chargé d'affaires of the unite… https://t.co/iymb398dlg
# hashtags : []
# ['chairman', 'verkhovna', 'rada', 'ukraine', 'ruslan', 'stefanchuk', 'meeting', 'charg', 'affaire', 'unite']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @mattklewis: really important podcast discussion here. ⁦@davidafrench⁩ &amp; ⁦@whignewtons⁩ raise serious questions about post-roe laws in r…
# hashtags : []
# ['rt', 'really', 'important', 'podcast', 'discussion', 'amp', 'raise', 'serious', 'question', 'post', 'roe', 'law', 'r']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# as much as i am all for prepping for the future elections. how? we were cheated out of this one. how do we prepare for the future ones?
# hashtags : []
# ['much', 'prepping', 'future', 'election', 'cheated', 'one', 'prepare', 'future', 'one']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @maximebernier: i, along with former premier brian peckford and others, am challenging trudeau’s ban on travel for the unvaccinated.
#
# t…
# hashtags : []
# ['rt', 'along', 'former', 'premier', 'brian', 'peckford', 'others', 'challenging', 'trudeau', 'ban', 'travel', 'unvaccinated']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @karafurunft: [thread] take note of all the benefits you can get as a 3d karafuru holder 📝
#
# 🎁  giving away 3 wl along this thread 🎁
#
# 1️⃣…
# hashtags : []
# ['rt', 'thread', 'take', 'note', 'benefit', 'get', 'karafuru', 'holder', 'giving', 'away', 'wl', 'along', 'thread']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @aamaadmiparty @arvindkejriwal there should be a debate between arvind kejriwal @arvindkejriwal  and mahathag @crpaatil
# hashtags : []
# ['debate', 'arvind', 'kejriwal', 'mahathag']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ilove_parkjimin: @614kh1s6zwuxxj3 @rose66664193 @bts_twt jimin jimin
# i am listening to hot trending song #withyou by #jimin #btsjimin o…
# hashtags : ['#withyou', '#jimin', '#btsjimin']
# ['rt', 'parkjimin', 'twt', 'jimin', 'jimin', 'listening', 'hot', 'trending', 'song', 'withyou', 'jimin', 'btsjimin']
# val : (0, 0, 1)   sentiments :  positive
#
#
# my dad just told me i need to learn to stfu(who talks to they kids like that, thats why he headed to a home😁) but i… https://t.co/mqkkuuiayw
# hashtags : []
# ['dad', 'told', 'need', 'learn', 'stfu', 'talk', 'kid', 'like', 'thats', 'headed', 'home']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @rebeccazandberg: education minister stephen lecce participated in a 2006 sigma chi event dubbed a "slave auction" while a leader of the…
# hashtags : []
# ['rt', 'education', 'minister', 'stephen', 'lecce', 'participated', 'sigma', 'chi', 'event', 'dubbed', 'slave', 'auction', 'leader']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @alakeoflagos: yo! a quick shoutout to all the haters, we just wanna say a big thank you 🙏
#
# ❤️😁❤️
# hashtags : []
# ['rt', 'yo', 'quick', 'shoutout', 'hater', 'wan', 'na', 'say', 'big', 'thank']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @isayan_58 i mean...it got to be soooo damn hard for you. i get it. 🙃
# hashtags : []
# ['mean', 'got', 'soooo', 'damn', 'hard', 'get']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @bchanarchive: i have romantic feelings for him
# hashtags : []
# ['rt', 'romantic', 'feeling']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# couldn't they shoot the occasional dog and say they thought it was a coyote going after their chickens?
# https://t.co/ihhz2ubkfs
# hashtags : []
# ['shoot', 'occasional', 'dog', 'say', 'thought', 'coyote', 'going', 'chicken']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# the !️ u.s. house of representatives approved the provision of assistance to ukraine for a record amount of $ 40 bi… https://t.co/mhc8ecepnl
# hashtags : []
# ['u', 'house', 'representative', 'approved', 'provision', 'assistance', 'ukraine', 'record', 'amount', 'bi']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @jimmcmahon: who else? 🐻⬇️
# hashtags : []
# ['rt', 'else']
# val : (0, 1, 0)   sentiments :  neutral
# @heartdived most days i am a museum of things i want to forget.
# hashtags : []
# ['day', 'museum', 'thing', 'want', 'forget']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @nocap: but fuck it they gone think i’m weak if i vent, i’ll keep it to myself.
# hashtags : []
# ['rt', 'fuck', 'gone', 'think', 'weak', 'vent', 'keep']
# val : (1, 0, 0)   sentiments :  negative
#
#
#
#
# rt @nybreezyyy_: i crave intimacy… i love holding hands, i love hugging, kissing, &amp; clinginess💗
# hashtags : []
# ['rt', 'crave', 'intimacy', 'love', 'holding', 'hand', 'love', 'hugging', 'kissing', 'amp', 'clinginess']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @caratjoeeeeeee: i know that 10m views are the goal, but can we really really push it to 15m to 20m views. i mean, there are so many thi…
# hashtags : []
# ['rt', 'know', 'view', 'goal', 'really', 'really', 'push', 'view', 'mean', 'many', 'thi']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @ganyueslover: welkin giveaway!! 🌙
# ----
# 1 winner through codashop
# ---
#
# rules :
# - rt this tweet
# - like &amp; rt my pinned
# - follow (optional…
# hashtags : []
# ['rt', 'welkin', 'giveaway', 'winner', 'codashop', 'rule', 'rt', 'tweet', 'like', 'amp', 'rt', 'pinned', 'follow', 'optional']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# it was love at first sight at last sight https://t.co/hzfosadhar
# hashtags : []
# ['love', 'first', 'sight', 'last', 'sight']
# val : (0, 0, 1)   sentiments :  positive
#
#
# thinking about stuff in my mind a lot of stuff do not know what going on with me just not right i do not feel right today
# hashtags : []
# ['thinking', 'stuff', 'mind', 'lot', 'stuff', 'know', 'going', 'right', 'feel', 'right', 'today']
# val : (0, 0, 1)   sentiments :  positive
#
#
# it was love at first sight at last sight https://t.co/aefb4py6ur
# hashtags : []
# ['love', 'first', 'sight', 'last', 'sight']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i couldn’t stop laughing. jangjun had an undie malfunction lmao. 🤣 https://t.co/ujvfxiwrmo
# hashtags : []
# ['stop', 'laughing', 'jangjun', 'undie', 'malfunction', 'lmao']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @bipolar4ever_18: i now announce that i'm officially a proud holder of #azuki #3554
# i'm sorry, and i sincerely apologize, but i've learn…
# hashtags : ['#azuki', '#3554']
# ['rt', 'announce', 'officially', 'proud', 'holder', 'azuki', 'sorry', 'sincerely', 'apologize', 'learn']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @drunkatdisney @angeladahlgren first of all. i would never put anyone through that torture. i don’t even put me thr… https://t.co/p7z1zurmsj
# hashtags : []
# ['first', 'would', 'never', 'put', 'anyone', 'torture', 'even', 'put', 'thr']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @badmintontalk: #thomascup2022 - standings
#
# as of 9 pm bangkok time, 11 may 2022
#
# indonesia and chinese taipei have secured top spot of…
# hashtags : ['#thomascup2022']
# ['rt', 'thomascup', 'standing', 'pm', 'bangkok', 'time', 'may', 'indonesia', 'chinese', 'taipei', 'secured', 'top', 'spot']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @thevivafrei: for everyone asking me to do a review on 2000 mules, barnes and i discussed it last stream. here is the highlight https://…
# hashtags : []
# ['rt', 'everyone', 'asking', 'review', 'mule', 'barnes', 'discussed', 'last', 'stream', 'highlight']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @jenwood90046133: 𝓞𝓷𝓮 𝔀𝓱𝓸 𝔀𝓪𝓵𝓴𝓼 𝓲𝓷 𝓵𝓸𝓿𝓮 𝓼𝓮𝓮
#
# https://t.co/dgcsw8bgki https://t.co/4ymslb15cb
# hashtags : []
# ['rt']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @festival_cannes: 🎙 4 major artists to meet the festival-goers of the 75th festival de cannes! #rendezvouswith javier bardem, agnès jaou…
# hashtags : ['#rendezvouswith']
# ['rt', 'cannes', 'major', 'artist', 'meet', 'festival', 'goer', 'th', 'festival', 'de', 'cannes', 'rendezvouswith', 'javier', 'bardem', 'agn', 'jaou']
# val : (0, 0, 1)   sentiments :  positive
#
#
# yoona's well guarded secret #2 revealed by her childhood friends: going into the boys bathroom was her speciality (… https://t.co/13wjpb58er
# hashtags : ['#2']
# ['yoona', 'well', 'guarded', 'secret', 'revealed', 'childhood', 'friend', 'going', 'boy', 'bathroom', 'speciality']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @anastacya_99: mom, i know you feel awful, but my prodigious snoot needs boops. https://t.co/9pqnyeg9g8
# hashtags : []
# ['rt', 'mom', 'know', 'feel', 'awful', 'prodigious', 'snoot', 'need', 'boops']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @nft_versee: @thertsygirl would you like to support me by buying a piece from my collection? floor price : 0.003 #eth(polygon) ($6,5) on…
# hashtags : ['#eth']
# ['rt', 'versee', 'would', 'like', 'support', 'buying', 'piece', 'collection', 'floor', 'price', 'eth', 'polygon']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @teamahlesunnat: today's talk
# do not abuse my sahabaؓ, for if any of you were to spend gold equal to (mountain of) uhud in charity, it w…
# hashtags : []
# ['rt', 'today', 'talk', 'abuse', 'sahaba', 'spend', 'gold', 'equal', 'mountain', 'uhud', 'charity', 'w']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @westhamhelp: ⚒️| ahead of mark noble's last match @londonstadium on sunday, we are giving away a signed mark noble home shirt!
#
# retweet…
# hashtags : []
# ['rt', 'ahead', 'mark', 'noble', 'last', 'match', 'sunday', 'giving', 'away', 'signed', 'mark', 'noble', 'home', 'shirt', 'retweet']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @secretsfrommygf: i'm straight but i let my roommate help me make some quick cash https://t.co/zsdzidvhdq
# hashtags : []
# ['rt', 'straight', 'let', 'roommate', 'help', 'make', 'quick', 'cash']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @realtyvp hi, apologize for my cold message.
#
# my name is mark. i would like to invite you to visit our website.
#
# y… https://t.co/pxar1jxayq
# hashtags : []
# ['hi', 'apologize', 'cold', 'message', 'name', 'mark', 'would', 'like', 'invite', 'visit', 'website']
# val : (1, 0, 0)   sentiments :  negative
#
#
# $tel don't miss the next move in a few hours.~
# 🔗https://t.co/e7j8glk3qb
# hashtags : []
# ['tel', 'miss', 'next', 'move', 'hour']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @mufaddal_vohra: mitchell marsh gets a wicket and he removes yashasvi jaiswal for a run a ball 19. rajasthan 2 down for 54.
# hashtags : []
# ['rt', 'vohra', 'mitchell', 'marsh', 'get', 'wicket', 'remove', 'yashasvi', 'jaiswal', 'run', 'ball', 'rajasthan']
# val : (1, 0, 0)   sentiments :  negative
#
#
# nahh they can’t beat me and my bro 5’8 but he can pick me up and toss me since i weigh less then him loll and my si… https://t.co/xs3fceqepq
# hashtags : []
# ['nahh', 'beat', 'bro', 'pick', 'toss', 'since', 'weigh', 'le', 'loll', 'si']
# val : (1, 0, 0)   sentiments :  negative
#
#
# it was love at first sight at last sight https://t.co/76xvukcevt
# hashtags : []
# ['love', 'first', 'sight', 'last', 'sight']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @binchanb: 3racha being absolutely adorable and chaotic on socials and i love it https://t.co/hbatvssur0
# hashtags : []
# ['rt', 'racha', 'absolutely', 'adorable', 'chaotic', 'social', 'love']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @my_meats i’ve got all kinds of bbq’s and mostly use a kettle or offset. i love messing with the fire adding wood w… https://t.co/zixr5dde2d
# hashtags : []
# ['meat', 'got', 'kind', 'bbq', 'mostly', 'use', 'kettle', 'offset', 'love', 'messing', 'fire', 'adding', 'wood', 'w']
# val : (0, 0, 1)   sentiments :  positive
#
#
# when i am down, i only have to think of you
# hashtags : []
# ['think']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @jenwood90046133: 𝓞𝓷𝓮 𝔀𝓱𝓸 𝔀𝓪𝓵𝓴𝓼 𝓲𝓷 𝓵𝓸𝓿𝓮 𝓼𝓮𝓮
#
# https://t.co/dgcsw8bgki https://t.co/4ymslb15cb
# hashtags : []
# ['rt']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @inluvqnf can i be the first to see it
# hashtags : []
# ['first', 'see']
# val : (0, 0, 1)   sentiments :  positive
#
#
# we supply straight or curved stairlifts, for a free quotation or a brochure please call us on 01761 417355… https://t.co/svurngkmu2
# hashtags : []
# ['supply', 'straight', 'curved', 'stairlifts', 'free', 'quotation', 'brochure', 'please', 'call', 'u']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @jenwood90046133: 𝓞𝓷𝓮 𝔀𝓱𝓸 𝔀𝓪𝓵𝓴𝓼 𝓲𝓷 𝓵𝓸𝓿𝓮 𝓼𝓮𝓮
#
# https://t.co/dgcsw8bgki https://t.co/4ymslb15cb
# hashtags : []
# ['rt']
# val : (0, 1, 0)   sentiments :  neutral
# that nigga tariq on power a slimey nigga
# hashtags : []
# ['nigga', 'tariq', 'power', 'slimey', 'nigga']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @i_am_khushi17 @shabsayed12 i really hope it's a plan
# hashtags : []
# ['khushi', 'really', 'hope', 'plan']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @knugent4118 thankfully @nhl playoffs &amp; the @bluejays will have my attention. leave it to @cpc_hq to schedule a deb… https://t.co/avxzxjrk6p
# hashtags : []
# ['thankfully', 'playoff', 'amp', 'attention', 'leave', 'hq', 'schedule', 'deb']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @jenwood90046133: 𝓞𝓷𝓮 𝔀𝓱𝓸 𝔀𝓪𝓵𝓴𝓼 𝓲𝓷 𝓵𝓸𝓿𝓮 𝓼𝓮𝓮
#
# https://t.co/dgcsw8bgki https://t.co/4ymslb15cb
# hashtags : []
# ['rt']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @onlyfanspostinl it’s just a job, why would he care? right?!?
# hashtags : []
# ['job', 'would', 'care', 'right']
# val : (0, 0, 1)   sentiments :  positive
#
#
# she woke up she couldnt up the street weather was good until he called me back i didnt know nor did i care i though… https://t.co/wtcphol4vu
# hashtags : []
# ['woke', 'couldnt', 'street', 'weather', 'good', 'called', 'back', 'didnt', 'know', 'care', 'though']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @ronfilipkowski jeez, devin, don't have a cow, man.
# hashtags : []
# ['jeez', 'devin', 'cow', 'man']
# val : (1, 0, 0)   sentiments :  negative
#
#
# the emotions that seeped through spread out i can’t control it anymore
# hashtags : []
# ['emotion', 'seeped', 'spread', 'control', 'anymore']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @jamiemarie027 that’s exactly what i meant ! 😂😂😂😂 damn boots fucking with my typing now!
# hashtags : []
# ['exactly', 'meant', 'damn', 'boot', 'fucking', 'typing']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @beoncloud_th: รอฟังเพลง"แค่เธอ why don't you stay"พร้อมกันได้ช่องทางmusic streaming 17.05.22 และเตรียมพบกับeng.verเร็วๆนี้
# “แค่เธอ why…
# hashtags : []
# ['rt', 'th', 'stay', 'music', 'streaming', 'eng', 'ver']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @ntellesexual same lmaoo. i need somebody else to remember cuz that shit really never crosses my mind at all.
# hashtags : []
# ['lmaoo', 'need', 'somebody', 'else', 'remember', 'cuz', 'shit', 'really', 'never', 'cross', 'mind']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @kbsoperfect: “ you look familiar “ lol shut up i’m always at home 😂
# hashtags : []
# ['rt', 'look', 'familiar', 'lol', 'shut', 'always', 'home']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @sensherrodbrown anyone who has encouraged, taught or instructed prepubescent children to sexually identify and/or… https://t.co/j31vbdg1sb
# hashtags : []
# ['anyone', 'encouraged', 'taught', 'instructed', 'prepubescent', 'child', 'sexually', 'identify']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @freakycouple186: i’m so horny i’m leaking, who wants to taste? 😈💦🦋 https://t.co/rk4g1glldr
# hashtags : []
# ['rt', 'horny', 'leaking', 'want', 'taste']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @vanlyxe: @benjaminbitcoin the other piece of the collection ❤️
#
# the fallen man
#
# the representation of a close person that i will always…
# hashtags : []
# ['rt', 'piece', 'collection', 'fallen', 'man', 'representation', 'close', 'person', 'always']
# val : (1, 0, 0)   sentiments :  negative
#
#
# like myself, lloyd smucker wants to reignite the american dream. he believes in the promise of america. he is endor… https://t.co/so8pbmgoxi
# hashtags : []
# ['like', 'lloyd', 'smucker', 'want', 'reignite', 'american', 'dream', 'belief', 'promise', 'america', 'endor']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @saranolee__ listen if she never acts again, i wouldn’t be upset because omg😭
# hashtags : []
# ['listen', 'never', 'act', 'upset', 'omg']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @briantheruller: things i miss from high school
#
# 1. fights at 7 am
#
# that’s all
# hashtags : []
# ['rt', 'thing', 'miss', 'high', 'school', 'fight']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @kenklippenstein: reminder that the white house anticipates 100 million new covid cases in the us by winter but congress still refuses t…
# hashtags : []
# ['rt', 'reminder', 'white', 'house', 'anticipates', 'million', 'new', 'covid', 'case', 'u', 'winter', 'congress', 'still', 'refuse']
# val : (0, 0, 1)   sentiments :  positive
#
#
#
#
# rt @mkolken: if trump wins in 2024 i predict that liberals will spontaneously combust, and i intend to roast marshmallows.
# hashtags : []
# ['rt', 'trump', 'win', 'predict', 'liberal', 'spontaneously', 'combust', 'intend', 'roast', 'marshmallow']
# val : (0, 0, 1)   sentiments :  positive
#
#
# 😹😹😹...and i see it😭
# hashtags : []
# ['see']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @jenwood90046133: 𝓞𝓷𝓮 𝔀𝓱𝓸 𝔀𝓪𝓵𝓴𝓼 𝓲𝓷 𝓵𝓸𝓿𝓮 𝓼𝓮𝓮
#
# https://t.co/dgcsw8bgki https://t.co/4ymslb15cb
# hashtags : []
# ['rt']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @whydidfiy oh, steve, i'm so sorry. do you have another appointment date?
# hashtags : []
# ['oh', 'steve', 'sorry', 'another', 'appointment', 'date']
# val : (1, 0, 0)   sentiments :  negative
#
#
# i faced a similar situation with united airlines at jfk. the flight was cancelled, supposedly due to bad weather, n… https://t.co/zcl4dmk88q
# hashtags : []
# ['faced', 'similar', 'situation', 'united', 'airline', 'jfk', 'flight', 'cancelled', 'supposedly', 'due', 'bad', 'weather', 'n']
# val : (1, 0, 0)   sentiments :  negative
#
#
# no matter how many fights you may get in https://t.co/g0ovfro976
# hashtags : []
# ['matter', 'many', 'fight', 'may', 'get']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @raxkingisdead: i simply would have made this announcement from any other room, wearing any other outfit
# hashtags : []
# ['rt', 'simply', 'would', 'made', 'announcement', 'room', 'wearing', 'outfit']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @atomic_flowerr @nuclearbby cait eat a fat one im tired of trynna be nice and yall shove it down my throat. smdddddd
# hashtags : []
# ['flowerr', 'cait', 'eat', 'fat', 'one', 'im', 'tired', 'trynna', 'nice', 'yall', 'shove', 'throat', 'smdddddd']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @oneandonlygo_: [malaysia 🇲🇾 go]#got7 new ep 《ep》
#
# 💰ktown rm73, 511
# aladin rm90, 630
# soundwave rm92, 644
# (include ems) +local postage rm…
# hashtags : ['#got7']
# ['rt', 'malaysia', 'go', 'got', 'new', 'ep', 'ep', 'ktown', 'rm', 'aladin', 'rm', 'soundwave', 'rm', 'include', 'em', 'local', 'postage', 'rm']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @greghands @beisgovuk @defragovuk @dwppressoffice @alexburghart @mimsdavies @pow_rebecca @kwasikwarteng @the_tuc pl… https://t.co/uc1occt71b
# hashtags : []
# ['rebecca', 'tuc', 'pl']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ptiofficial: maleeka ali bokhari (@malbokhari ) talks to media regarding article 63-a and the ongoing case! 1/2 #امپورٹڈ__حکومت__نامنظو…
# hashtags : []
# ['rt', 'maleeka', 'ali', 'bokhari', 'talk', 'medium', 'regarding', 'article', 'ongoing', 'case']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @ft_canaanland i received
# hashtags : []
# ['canaanland', 'received']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# fact: 100% of these people are twitter pundits with substack newsletters. philosophy pay good.
# hashtags : []
# ['fact', 'people', 'twitter', 'pundit', 'substack', 'newsletter', 'philosophy', 'pay', 'good']
# val : (0, 0, 1)   sentiments :  positive
#
#
# over to you jack @bootstrapcook - tear the little fascist a new one ..
# hashtags : []
# ['jack', 'tear', 'little', 'fascist', 'new', 'one']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @maize_raven: s a f i r a  y a k k u z a
# (24yo - 5️⃣0️⃣ loads)
#
# @safirayakkuza
#
# #premiumbukkake
# #gokkun
# #bukkake
# @marinagoldxx
# @kxtten_…
# hashtags : ['#premiumbukkake', '#gokkun', '#bukkake']
# ['rt', 'raven', 'f', 'r', 'k', 'k', 'u', 'z', 'yo', 'load', 'premiumbukkake', 'gokkun', 'bukkake']
# val : (1, 0, 0)   sentiments :  negative
#
#
# no matter how many fights you may get in https://t.co/8bxvf2aawr
# hashtags : []
# ['matter', 'many', 'fight', 'may', 'get']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @daralebrun @mwolfers also,
# mccain wasn't a fascist (to be fair, palin is)
# mccain didn't win
# hashtags : []
# ['also', 'mccain', 'fascist', 'fair', 'palin', 'mccain', 'win']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @nairobiracina @aashiq_awara281 @singhswati2021 @rahulgandhi never do any baqwas from next time onwards - here are… https://t.co/shqspz3bun
# hashtags : []
# ['awara', 'never', 'baqwas', 'next', 'time', 'onwards']
# val : (0, 1, 0)   sentiments :  neutral
# $tlm all that you need to know' ,shorts haven't covered a single share,  https://t.co/cjkmeqlcpf
# hashtags : []
# ['tlm', 'need', 'know', 'short', 'covered', 'single', 'share']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @keldorjedii: ewan: “i like them. episode 3 was a really good movie.”
#
# hayden: “it’s a phenomenal film!” https://t.co/9br7ifishu
# hashtags : []
# ['rt', 'ewan', 'like', 'episode', 'really', 'good', 'movie', 'hayden', 'phenomenal', 'film']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @hoopki that's so rude -_- stop saying stupid things to hoopki or i will unleash my slavic personality on the lot of you
# hashtags : []
# ['rude', 'stop', 'saying', 'stupid', 'thing', 'hoopki', 'unleash', 'slavic', 'personality', 'lot']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @chelsea1992luv: i baked a crappy cake. do you like? https://t.co/melnnybgiv
# hashtags : []
# ['rt', 'baked', 'crappy', 'cake', 'like']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @nytimes whoever wrote this headline is a piece of garbage.
# hashtags : []
# ['whoever', 'wrote', 'headline', 'piece', 'garbage']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @fleuroteur i really think it wouldn't be a thing if society allowed men to just admit when they're scared
# hashtags : []
# ['really', 'think', 'thing', 'society', 'allowed', 'men', 'admit', 'scared']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @smithannyona: a marriage built in christ is a marriage built to last !!!
# hashtags : []
# ['rt', 'marriage', 'built', 'christ', 'marriage', 'built', 'last']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @milkymoonss: seems like some of them changed their intro:
#
# 🐯 with 3 hearts
# 🦝 existence you can't not have
# 🐧 snow white leader
# 🦊 really…
# hashtags : []
# ['rt', 'seems', 'like', 'changed', 'intro', 'heart', 'existence', 'snow', 'white', 'leader', 'really']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @byakuxgo: do you guys know how freaking stupid you sound, like are you seriously that stupid to believe some random people on the inter…
# hashtags : []
# ['rt', 'guy', 'know', 'freaking', 'stupid', 'sound', 'like', 'seriously', 'stupid', 'believe', 'random', 'people', 'inter']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @therickydavila: just so we’re clear, susan collins is such a fraud that a message written in chalk on a sidewalk asking her to just sup…
# hashtags : []
# ['rt', 'clear', 'susan', 'collins', 'fraud', 'message', 'written', 'chalk', 'sidewalk', 'asking', 'sup']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @nickcho i'm wondering what percentage are emails like "thanks for sharing the gourmet strawberries, dad!" (those v… https://t.co/jjl6xkfo2l
# hashtags : []
# ['wondering', 'percentage', 'email', 'like', 'thanks', 'sharing', 'gourmet', 'strawberry', 'dad', 'v']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @golub: chinese television crew caught the moment of launching the turret of a russian tank into the sky https://t.co/gspcsttlmd
# hashtags : []
# ['rt', 'chinese', 'television', 'crew', 'caught', 'moment', 'launching', 'turret', 'russian', 'tank', 'sky']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i have the biggest crush on this girl in my asl class https://t.co/t3gdjywsl4
# hashtags : []
# ['biggest', 'crush', 'girl', 'asl', 'class']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @somakazima: this is what they mean by god gives his toughest battles to his strongest warriors. i am weak https://t.co/zc1rmc9ghm
# hashtags : []
# ['rt', 'mean', 'god', 'give', 'toughest', 'battle', 'strongest', 'warrior', 'weak']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @b52malmet: @mmcauliff i have received multiple invitations to protest outside of chuck’s place in park slope, brooklyn. i have always d…
# hashtags : []
# ['rt', 'received', 'multiple', 'invitation', 'protest', 'outside', 'chuck', 'place', 'park', 'slope', 'brooklyn', 'always']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @kobesystem143: not gonna lie, @azukiofficial art looks a lot worse when it’s sub 10 eth
# hashtags : []
# ['rt', 'gon', 'na', 'lie', 'art', 'look', 'lot', 'worse', 'sub', 'eth']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @vijayprashad: fellow reporter, sherin abu aqla (age 51), the voice of palestine, executed by the state of israel while she was doing he…
# hashtags : []
# ['rt', 'fellow', 'reporter', 'sherin', 'abu', 'aqla', 'age', 'voice', 'palestine', 'executed', 'state', 'israel']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# it's not a conspiracy if niggas are doing the dumb shit.
# hashtags : []
# ['conspiracy', 'nigga', 'dumb', 'shit']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @bamsmackpow: bring the legends of tomorrow back for one more adventure.
#
# one final season, a miniseries or a tv movie, focusing on the…
# hashtags : []
# ['rt', 'bring', 'legend', 'tomorrow', 'back', 'one', 'adventure', 'one', 'final', 'season', 'miniseries', 'tv', 'movie', 'focusing']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @iamhaunted13: ur lying this was not a year ago i refuse https://t.co/hjddgommt9
# hashtags : []
# ['rt', 'ur', 'lying', 'year', 'ago', 'refuse']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @jjjjjjjjjjjjd 5 side in a group that plays at lunch time and i play with my uni team in training sometimes
# hashtags : []
# ['side', 'group', 'play', 'lunch', 'time', 'play', 'uni', 'team', 'training', 'sometimes']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @adversereports: skin ulcer at the injection site of #pfizer bnt162b2 mrna
# a 79-year-old man was referred to us with a complaint of ski…
# hashtags : ['#pfizer']
# ['rt', 'skin', 'ulcer', 'injection', 'site', 'pfizer', 'bnt', 'b', 'mrna', 'year', 'old', 'man', 'referred', 'u', 'complaint', 'ski']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @teddybaguilatjr i feel you o.po
# hashtags : []
# ['feel', 'po']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @robinbieber007 @_ifeomasinachi 0xc6473856a74732374ec3af4f2b04cb94a28f60b1
#
# i would be very grateful if you gave it to me 🥳
# hashtags : []
# ['ifeomasinachi', 'xc', 'ec', 'af', 'f', 'b', 'cb', 'f', 'b', 'would', 'grateful', 'gave']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @taj_ali1: absolutely heartbreaking news. veteran al jazeera correspondent shireen abu akleh has passed away after being in shot in the…
# hashtags : []
# ['rt', 'ali', 'absolutely', 'heartbreaking', 'news', 'veteran', 'al', 'jazeera', 'correspondent', 'shireen', 'abu', 'akleh', 'passed', 'away', 'shot']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @penguinr90 @drdistracto0 @kgnmul @jim_jordan you need to read the law.  come@on man stop being a stupid son of a b-tch
# hashtags : []
# ['jordan', 'need', 'read', 'law', 'come', 'man', 'stop', 'stupid', 'son', 'b', 'tch']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @bajanussy where you at i’m wit it
# ...
# hashtags : []
# ['rt', 'son', 'chaeyoung', 'floor']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @wediraya7: as the ￼gov’t continues its blockade of tigray, the #childrenoftigray are paying the highest price. gov’s policy is to stunt…
# hashtags : ['#childrenoftigray']
# ['rt', 'gov', 'continues', 'blockade', 'tigray', 'childrenoftigray', 'paying', 'highest', 'price', 'gov', 'policy', 'stunt']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @philosophercrip: #abortionisadisabilityrightsissue 🧵: i and my spouse are both little people and both support abortion rights for every…
# hashtags : ['#abortionisadisabilityrightsissue']
# ['rt', 'abortionisadisabilityrightsissue', 'spouse', 'little', 'people', 'support', 'abortion', 'right', 'every']
# val : (1, 0, 0)   sentiments :  negative
#
#
# i don't compliment everybody.. so if i do, you're special to me..
# hashtags : []
# ['compliment', 'everybody', 'special']
# val : (0, 0, 1)   sentiments :  positive
#
#
#
#
# rt @timryan: fighting for ohio means:
#
# ✅ making it easier to join a union
# ✅ investing in our kids and cutting taxes for working families
# ✅…
# hashtags : []
# ['rt', 'fighting', 'ohio', 'mean', 'making', 'easier', 'join', 'union', 'investing', 'kid', 'cutting', 'tax', 'working', 'family']
# val : (1, 0, 0)   sentiments :  negative
#
#
# no account should have less than 1k followers 👀
#
# drop an emoji down below and follow everyone who likes it 🤝
#
# retwe… https://t.co/01c8fh997k
# hashtags : []
# ['account', 'le', 'k', 'follower', 'drop', 'emoji', 'follow', 'everyone', 'like', 'retwe']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @craziecrissie maan i'm jealous of your nia figures. i only have two so far and i needa get more
# hashtags : []
# ['maan', 'jealous', 'nia', 'figure', 'two', 'far', 'needa', 'get']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @flow_key_1000: @realflokiinu @notawhaleqq get in on the valhalla stream on twitch.
#
# you just have to come and see for yourself how grea…
# hashtags : []
# ['rt', 'key', 'get', 'valhalla', 'stream', 'twitch', 'come', 'see', 'grea']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i finally got a reply from a homie who disappeared like this and it was because he got a goth gf and a decent job.… https://t.co/i2mifckqi0
# hashtags : []
# ['finally', 'got', 'reply', 'homie', 'disappeared', 'like', 'got', 'goth', 'gf', 'decent', 'job']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @ggreenwald @getcallin it’s all shits and giggles until the washington mall burns in a fiery russian inferno. but then it’s a bit late, huh.
# hashtags : []
# ['shit', 'giggle', 'washington', 'mall', 'burn', 'fiery', 'russian', 'inferno', 'bit', 'late', 'huh']
# val : (1, 0, 0)   sentiments :  negative
#
#
# the eu is investing in a healthier future for all 🇪🇺
#
# discover the animated explainer video esn produced to raise a… https://t.co/cx9fkxk5ey
# hashtags : []
# ['eu', 'investing', 'healthier', 'future', 'discover', 'animated', 'explainer', 'video', 'esn', 'produced', 'raise']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# as much as i wanted it, idc anymore. take care and do you.
# hashtags : []
# ['much', 'wanted', 'idc', 'anymore', 'take', 'care']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @proffeynman: the difference between a good student and a great one is that a good student is concerned more about the outcome while a g…
# hashtags : []
# ['rt', 'difference', 'good', 'student', 'great', 'one', 'good', 'student', 'concerned', 'outcome', 'g']
# val : (0, 0, 1)   sentiments :  positive
#
#
# am i actually going to see twice
# hashtags : []
# ['actually', 'going', 'see', 'twice']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @mrsmoviefan_67: @amazonfreevee i think you know me well enough @amazonfreevee to know my answer…
#
# #leverageredemption https://t.co/8um…
# hashtags : ['#leverageredemption']
# ['rt', 'think', 'know', 'well', 'enough', 'know', 'answer', 'leverageredemption']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @poli_pol1: and never gave up his smile. not once!  https://t.co/lkn7gnjyrt
# hashtags : []
# ['rt', 'pol', 'never', 'gave', 'smile']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @chandbashaece41: 'if i die under mysterious circumstances, it’s been nice knowin ya #百家乐 #龙虎斗 #极速赛车 #幸运飞艇 #时时彩 #极速快三 #彩票 #pg电子 #棋牌 #ag真…
# hashtags : ['#pg', '#ag']
# ['rt', 'die', 'mysterious', 'circumstance', 'nice', 'knowin', 'ya', 'pg', 'ag']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @suryafx_: #don arrival in 2days😌💛🔥
#
# a kutty mashup🌝
# @siva_kartikeyan na.. hope you'll see this🚶
#
# @dir_cibi @bala_actor @kalaiarasu_ @al…
# hashtags : ['#don']
# ['rt', 'arrival', 'day', 'kutty', 'mashup', 'kartikeyan', 'na', 'hope', 'see', 'cibi', 'actor']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @misspaviichenko: yuri knorozov, the linguist who deciphered the maya script, listed his cat asya as a co-author on his work but the edi…
# hashtags : []
# ['rt', 'yuri', 'knorozov', 'linguist', 'deciphered', 'maya', 'script', 'listed', 'cat', 'asya', 'co', 'author', 'work', 'edi']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @startup_space1: 🔘 @enjinstarter will be hosting an #ino + #nft sale for @appcalo! 🎉
#
# 🗓 ino date: 20th may, 2022
# 💥 calo metaverse is a h…
# hashtags : ['#ino', '#nft']
# ['rt', 'space', 'hosting', 'ino', 'nft', 'sale', 'ino', 'date', 'th', 'may', 'calo', 'metaverse', 'h']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @freedomhaswon: your vaccine protects as well as your operating system.
# maybe try mcafee?
# besides, aren’t you the expert in these things…
# hashtags : []
# ['rt', 'vaccine', 'protects', 'well', 'operating', 'system', 'maybe', 'try', 'mcafee', 'besides', 'expert', 'thing']
# val : (0, 1, 0)   sentiments :  neutral
# rt @chandbashaece41: 'if i die under mysterious circumstances, it’s been nice knowin ya #百家乐 #龙虎斗 #极速赛车 #幸运飞艇 #时时彩 #极速快三 #彩票 #pg电子 #棋牌 #ag真…
# hashtags : ['#pg', '#ag']
# ['rt', 'die', 'mysterious', 'circumstance', 'nice', 'knowin', 'ya', 'pg', 'ag']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @a_cold_rain: they couldn’t have the truth coming out before the election.
# hashtags : []
# ['rt', 'cold', 'rain', 'truth', 'coming', 'election']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i went to amsterdam without u
# hashtags : []
# ['went', 'amsterdam', 'without', 'u']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @missufe: $200 | 2.800.0000 idr in 24 hours 🦄
#
# - rt &amp; follow @toushisamurai45
#
# - register on this link (post proof)
# link: https://t.co/…
# hashtags : []
# ['rt', 'idr', 'hour', 'rt', 'amp', 'follow', 'register', 'link', 'post', 'proof', 'link']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# according to a recent survey from @deloitte, 1/3 of employees indicate they would like to see more mental health su… https://t.co/pybbsgc6l9
# hashtags : []
# ['according', 'recent', 'survey', 'employee', 'indicate', 'would', 'like', 'see', 'mental', 'health', 'su']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @kai_ros__: i am a small account with no interactions do your worst https://t.co/dwajdyjvgv
# hashtags : []
# ['rt', 'ro', 'small', 'account', 'interaction', 'worst']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @ptiofficial: chairman pti @imrankhanpti held a meeting with @shkhrasheed earlier today in bani gala. #امپورٹڈ__حکومت__نامنظور https://t…
# hashtags : []
# ['rt', 'chairman', 'pti', 'held', 'meeting', 'earlier', 'today', 'ban', 'gala']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# pocahontas was on the news saying "the supreme court justices had the fencing put up around the court house."
#
# she… https://t.co/wav9vvhgxb
# hashtags : []
# ['pocahontas', 'news', 'saying', 'supreme', 'court', 'justice', 'fencing', 'put', 'around', 'court', 'house']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @jaiyejejeomo: everything a yahoo boy needs in a girl dey this one body 😂😂😂😂😂 https://t.co/zwbsqjejei
# hashtags : []
# ['rt', 'everything', 'yahoo', 'boy', 'need', 'girl', 'dey', 'one', 'body']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @nash076: if you're both single but living together on social security, you can each earn $25k before you get taxed.
#
# if you're married,…
# hashtags : []
# ['rt', 'single', 'living', 'together', 'social', 'security', 'earn', 'k', 'get', 'taxed', 'married']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @90dnt: i still love him but it hurts too much
# hashtags : []
# ['rt', 'still', 'love', 'hurt', 'much']
# val : (0, 0, 1)   sentiments :  positive
#
#
# sushant 4 women empowerment✨❤️
# hashtags : []
# ['sushant', 'woman', 'empowerment']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @chandbashaece41: 'if i die under mysterious circumstances, it’s been nice knowin ya #百家乐 #龙虎斗 #极速赛车 #幸运飞艇 #时时彩 #极速快三 #彩票 #pg电子 #棋牌 #ag真…
# hashtags : ['#pg', '#ag']
# ['rt', 'die', 'mysterious', 'circumstance', 'nice', 'knowin', 'ya', 'pg', 'ag']
# val : (0, 0, 1)   sentiments :  positive
#
#
# yo wtf i literally gasped--
# hashtags : []
# ['yo', 'wtf', 'literally', 'gasped']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @snarkylicious: i hate to tell you this but a clip of a headline doesn't really tell the whole story. and if you think pelosi was the pr…
# hashtags : []
# ['rt', 'hate', 'tell', 'clip', 'headline', 'really', 'tell', 'whole', 'story', 'think', 'pelosi', 'pr']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @alyorubawi and come up with a conference themselves
# hashtags : []
# ['come', 'conference']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @macjay72: @rupahuq aaand that’s why labour will not be in power for a very long time. tweets like this. #bookmarked 🙄
# hashtags : ['#bookmarked']
# ['rt', 'aaand', 'labour', 'power', 'long', 'time', 'tweet', 'like', 'bookmarked']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @majorgauravarya: former cabinet member and @imrankhanpti loyalist @shabazgil wants a “patta” or collar around the necks of political ri…
# hashtags : []
# ['rt', 'former', 'cabinet', 'member', 'loyalist', 'want', 'patta', 'collar', 'around', 'neck', 'political', 'ri']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @destinedparadox getting raina and benching him would have been a bigger disrespect to him.
# hashtags : []
# ['getting', 'raina', 'benching', 'would', 'bigger', 'disrespect']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @alexadelman: 🔥breaking: the @trylolli team and i are excited to announce our newest partnership with @shakeshack!
#
# lolli users can now…
# hashtags : []
# ['rt', 'breaking', 'team', 'excited', 'announce', 'newest', 'partnership', 'lolli', 'user']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @han2thet: i got a comment yesterday that has made me quite angry &amp; this shouldn’t need to be said. whether it’s starmer or corbyn or wh…
# hashtags : []
# ['rt', 'got', 'comment', 'yesterday', 'made', 'quite', 'angry', 'amp', 'need', 'said', 'whether', 'starmer', 'corbyn', 'wh']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @reece_youngking: i’m the best rapper in africa.
# hashtags : []
# ['rt', 'youngking', 'best', 'rapper', 'africa']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @repgregsteube: tonight, i voted against an additional $40 billion of new funding in response to russia’s invasion of ukraine.
# hashtags : []
# ['rt', 'tonight', 'voted', 'additional', 'billion', 'new', 'funding', 'response', 'russia', 'invasion', 'ukraine']
# val : (0, 0, 1)   sentiments :  positive
#
#
# remember when i ended brittany broski?
# hashtags : []
# ['remember', 'ended', 'brittany', 'broski']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @joshjay1969: @angelarayner i have a few words too: durham, party, pre-arranged, curry, drinks, covid, rule-breaking. #durhampartygate #…
# hashtags : ['#durhampartygate']
# ['rt', 'word', 'durham', 'party', 'pre', 'arranged', 'curry', 'drink', 'covid', 'rule', 'breaking', 'durhampartygate']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @ambforgottenimp: i've got a few client projects to share with you all soon, but might be after comic con in a few weeks. until then her…
# hashtags : []
# ['rt', 'got', 'client', 'project', 'share', 'soon', 'might', 'comic', 'con', 'week']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @lefemboy69: if i was your femboy wife i'd wake you up every day with breakfast in bed dressed like this.
# #gay #femboy #twink #trap http…
# hashtags : ['#gay', '#femboy', '#twink', '#trap']
# ['rt', 'femboy', 'wife', 'wake', 'every', 'day', 'breakfast', 'bed', 'dressed', 'like', 'gay', 'femboy', 'twink', 'trap', 'http']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @db4ke94 @paulsites1 @camelot331 pedos don’t deserve rights, its a travesty we don’t  put kid diddlers to death.
# hashtags : []
# ['pedos', 'deserve', 'right', 'travesty', 'put', 'kid', 'diddlers', 'death']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @lul_leak don’t say that dude. you’re valuable and you’re living a long life. cut that shit out!
# hashtags : []
# ['leak', 'say', 'dude', 'valuable', 'living', 'long', 'life', 'cut', 'shit']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @babyboymonaghan i have some cool rocks, they've probably been around for a considerable length of time
# hashtags : []
# ['cool', 'rock', 'probably', 'around', 'considerable', 'length', 'time']
# val : (0, 0, 1)   sentiments :  positive
#
#
# dog i smoked like literally the tiniest speck of weed last night and i still somehow got a good buzz 😭
# hashtags : []
# ['dog', 'smoked', 'like', 'literally', 'tiniest', 'speck', 'weed', 'last', 'night', 'still', 'somehow', 'got', 'good', 'buzz']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @srk_allu_dhf: difference between a modest king srk and a single expression arrogant actor magesh babu
# hashtags : []
# ['rt', 'allu', 'dhf', 'difference', 'modest', 'king', 'srk', 'single', 'expression', 'arrogant', 'actor', 'magesh', 'babu']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i’m craving something sweet rn
# hashtags : []
# ['craving', 'something', 'sweet', 'rn']
# val : (0, 0, 1)   sentiments :  positive
#
#
#
#
# lic's grey market premium turns negative
# .
# from rs. 95 a share, it has fallen by rs. 15 per share on wednesday.
# .
# a… https://t.co/y2xvfwcmvy
# hashtags : []
# ['lic', 'grey', 'market', 'premium', 'turn', 'negative', 'r', 'share', 'fallen', 'r', 'per', 'share', 'wednesday']
# val : (1, 0, 0)   sentiments :  negative
# rt @vindesigns2013: twitter i’m looking for a place where i can get a custom dog tag shaped like a race car or a helmet. any ideas? searchi…
# hashtags : []
# ['rt', 'twitter', 'looking', 'place', 'get', 'custom', 'dog', 'tag', 'shaped', 'like', 'race', 'car', 'helmet', 'idea', 'searchi']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @irharambi i said it!! it’s like people who cry ‘don’t use the word coconut it’s racist :@ not my fault i grew up a… https://t.co/glewq3tytt
# hashtags : []
# ['said', 'like', 'people', 'cry', 'use', 'word', 'coconut', 'racist', 'fault', 'grew']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# todays the day i got california mfs!!!!!
# hashtags : []
# ['today', 'day', 'got', 'california', 'mf']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ynahgives: $4 in 30mins
#
# — rt + rt &amp; like the twt below ⬇️
# hashtags : []
# ['rt', 'min', 'rt', 'rt', 'amp', 'like', 'twt']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @archie_th1: 📢 are you affected by the #strangeınu situation?  #archieneko ceo,#archie meowfia wants to lend a helping hand by offering…
# hashtags : ['#strange', '#archieneko', '#archie']
# ['rt', 'th', 'affected', 'strange', 'nu', 'situation', 'archieneko', 'ceo', 'archie', 'meowfia', 'want', 'lend', 'helping', 'hand', 'offering']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @eddie_rado  @toddonfranchise alpha dog is a true story too. crazy stuff.
# hashtags : []
# ['rado', 'alpha', 'dog', 'true', 'story', 'crazy', 'stuff']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @wonfeedz: what they see                     what i see https://t.co/njfjl6cld3
# hashtags : []
# ['rt', 'see', 'see']
# val : (0, 1, 0)   sentiments :  neutral
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16044/1339079918.py in <module>
#       1 for msg in consumer:
#       2         #print(str(1));
# ----> 3         time.sleep(2)
#       4
#       5         data= text_lowercase(msg.value)
#
# KeyboardInterrupt:
