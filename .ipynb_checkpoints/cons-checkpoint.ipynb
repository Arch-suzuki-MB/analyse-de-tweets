# %%
pip install inflect
# Out:
# Collecting inflect
#   Downloading inflect-5.6.0-py3-none-any.whl (33 kB)
# Installing collected packages: inflect
# Successfully installed inflect-5.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\users\hezza\anaconda3\lib\site-packages (from textblob) (3.6.5)
# Requirement already satisfied: click in c:\users\hezza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.3)
# Requirement already satisfied: joblib in c:\users\hezza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hezza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: tqdm in c:\users\hezza\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.62.3)
# Requirement already satisfied: colorama in c:\users\hezza\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install elasticsearch==7.0.0
# Out:
# Collecting elasticsearch==7.0.0Note: you may need to restart the kernel to use updated packages.
#
#   Downloading elasticsearch-7.0.0-py2.py3-none-any.whl (80 kB)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\hezza\anaconda3\lib\site-packages (from elasticsearch==7.0.0) (1.26.7)
# Installing collected packages: elasticsearch
# Successfully installed elasticsearch-7.0.0

# %%
import time
import inflect
import re
import string
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.corpus import stopwords # used for preprocessing
from nltk.stem import WordNetLemmatizer # used for preprocessing
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
from operator import add
from kafka import KafkaConsumer
import json
from textblob import TextBlob
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\safae\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\safae\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\safae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from elasticsearch import Elasticsearch
# create instance of elasticsearch
es = Elasticsearch([{'host':'localhost','port':9200}])

# %%
es.ping()
# Out:
# False

# %%
topic_name = 'test'
# ------------------- your consummer ------------------- -----
consumer = KafkaConsumer(
    topic_name,
     bootstrap_servers=['localhost:9092'],
     auto_offset_reset='latest',
     enable_auto_commit=True,
     auto_commit_interval_ms =  5000,
     fetch_max_bytes = 128,
     max_poll_records = 100,
     )

# %%
#-------------------Traitement du data -----------------------

def remove_urls(text):
    new_text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^A-Za-z# \t])|(\w+:\/\/\S+)"," ",text).split())
    return new_text

# make all text lowercase
def text_lowercase(text):
    return text.lower()

# make all text Uppercase

def text_uppercase(text):
    return text.upper()

# %%
#----------delete numbers from text ---------

def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result

# %%
# --------------- delete ponctuation existent on text ----------

def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)


# ----------------convert list to words ---------------
def tokenize(text):
    text = word_tokenize(text)
    return text

# %%
#----------- delete words non significant ---------
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    text = [i for i in text if not i in stop_words]
    return text

# %%
# ---------------get the origins of words--------------
lemmatizer = WordNetLemmatizer()
def lemmatize(text):
    text = [lemmatizer.lemmatize(token) for token in text]
    return text

# %%
# -------------remplace all number with word notation-----------
def numbers_to_char(text):
    wordtoken = nltk.word_tokenize(text)
    p = inflect.engine()
    new_Text = []
    for word in wordtoken:
        if word.isdigit():
            newword = p.number_to_words(word)
            new_Text.append(newword)
        else:
            new_Text.append(word)
    return new_Text

# %%
#--------------------------end analyse feedback using textBlob--------------------------------
def analyze_sentiment(text):
    testimonial = TextBlob(text)
    return testimonial.sentiment.polarity
def get_sentiment_tuple(sent):
    neutral_threshold = 0.05
    if sent >= neutral_threshold:       # positive
        return (0, 0, 1),"positive"
    elif sent > -neutral_threshold:     # neutral
        return (0, 1, 0),"neutral"
    else:                               # negative
        return (1, 0, 0),"negative"

# %%
counter=0 
def topHashtag(text):
    return text.split(" ")
def getNouns(txt):
    blob = TextBlob(txt)
    print(blob.noun_phrases)

# %%
for msg in consumer:
        #print(str(1));
        time.sleep(2)
      
        data= text_lowercase(msg.value)
        
        
        #------hashtages----------------------------------------------
        dict_data=json.loads(data)
        key="text"
        if (key in dict_data.keys()):
            print(dict_data["text"])
            hashtags = re.findall("#[a-zA-Z0-9_]{1,200}", dict_data["text"])
            print("hashtags :",hashtags)
       
        #---feedback-----------------------------------
            tweets=TextBlob(dict_data["text"])
            sentiments=analyze_sentiment(dict_data["text"])

        #----------best and bad tweets ------------------
            frequencetweets= text_lowercase(dict_data["text"])
            frequencetweets=remove_urls(frequencetweets)

        #----------- frequency of words---------------
            filtreData= text_lowercase(dict_data["text"])
            filtredData=remove_urls(filtreData)
            filtredData=remove_punctuation(filtredData)
            filtredData=tokenize(filtredData)
            filtredData=remove_stopwords(filtredData)
            FrequencesMots=lemmatize(filtredData)
  
            print(FrequencesMots)
            analysentimens,feedback=get_sentiment_tuple(sentiments)
            print("val :",analysentimens,"  sentiments : ",feedback)
       
        # ------------------- send all result to elastic search --------------------- 
            
            es.index(index="tweeter_index" ,
                    doc_type="test_doc",
                    body={
                            "author": dict_data["user"]["screen_name"],
                            "date": dict_data["created_at"],
                            "message": dict_data["text"], 
                            "sentimentsPer":sentiments,
                            "feedback":feedback,
                            "hashtag":hashtags,
                            "FrequencMots":FrequencesMots,
                            "FrequenceTweets":frequencetweets
                    }
                )
           
             
        #-------------------------- optional ---------------------
        #time.sleep(5)
        #print(str(tweets))
        print('\n')
# Out:
# rt @msibigugumsibi8: it’s so important to have friendship in your partner. imagine a relationship with friendship, where you able to be you…
# hashtags : []
# ['rt', 'important', 'friendship', 'partner', 'imagine', 'relationship', 'friendship', 'able']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @coinwebofficial: dapps built on top of coinweb are able utilize the underlying blockchains they are connected to.
# should one of them h…
# hashtags : []
# ['rt', 'dapps', 'built', 'top', 'coinweb', 'able', 'utilize', 'underlying', 'blockchains', 'connected', 'one', 'h']
# val : (0, 0, 1)   sentiments :  positive
#
#
# colored lineart commission for @mateo_redfield 🤍💜💕💖🍈🍈🍑💦looks like she is enjoying the paranormal company of shy~👀💕💖… https://t.co/df1dkncia0
# hashtags : []
# ['colored', 'lineart', 'commission', 'redfield', 'look', 'like', 'enjoying', 'paranormal', 'company', 'shy']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @sunnylovelife: at this part, bin was singing 'wherever u r, i will be there' while showing their team ring 😭🥺😭🥺
# #candysugarpop #drive_…
# hashtags : ['#candysugarpop', '#drive_']
# ['rt', 'part', 'bin', 'singing', 'wherever', 'u', 'r', 'showing', 'team', 'ring', 'candysugarpop', 'drive']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @0xskrr: 🎏@xtexchange &amp; @0xskrr
#
# 💸giveaway $300
# ⏱24 hours
#
# 1️⃣ rt
# 2️⃣ register with this link: https://t.co/k3on2wjocb
# (comment proof)-…
# hashtags : []
# ['rt', 'amp', 'giveaway', 'hour', 'rt', 'register', 'link', 'comment', 'proof']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# is it possible for the metaverse to be a safe place?
#
# in a world where you can virtually be whoever or wherever you… https://t.co/r2zohvllxt
# hashtags : []
# ['possible', 'metaverse', 'safe', 'place', 'world', 'virtually', 'whoever', 'wherever']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @ben_rosen: listen, there are responsible gun owners who just enjoying hunting and i want to make it clear that i don’t care at all and…
# hashtags : []
# ['rt', 'rosen', 'listen', 'responsible', 'gun', 'owner', 'enjoying', 'hunting', 'want', 'make', 'clear', 'care']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @joyturamuhawe: are you planning on having your child’s graduation party at home but are thinking twice because your pavers are dirty!?…
# hashtags : []
# ['rt', 'planning', 'child', 'graduation', 'party', 'home', 'thinking', 'twice', 'pavers', 'dirty']
# val : (0, 1, 0)   sentiments :  neutral
#
#
#
#
# @mubarakkindam @yakasai_aysha what r u doing on my timeline 🤔🤔
# hashtags : []
# ['aysha', 'r', 'u', 'timeline']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# afd - call for expressions of intent for cso 2022 projects. https://t.co/1f0s5hbzwm
# hashtags : []
# ['afd', 'call', 'expression', 'intent', 'cso', 'project']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @imnini_: i’ve washed my hands with people. at some point you really gotta realize some people just stuck in their ways &amp; there’s nothin…
# hashtags : []
# ['rt', 'washed', 'hand', 'people', 'point', 'really', 'got', 'ta', 'realize', 'people', 'stuck', 'way', 'amp', 'nothin']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @movieaviator: i mean they could made some basic changes to the new suit to make it look more elegant but no... #theflash #restorethesny…
# hashtags : ['#theflash', '#restorethesny']
# ['rt', 'mean', 'could', 'made', 'basic', 'change', 'new', 'suit', 'make', 'look', 'elegant', 'theflash', 'restorethesny']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @johncusack: we live in a half fascist country -  corporations are all in as long as the profits keep rolling in .
# supreme court taken…
# hashtags : []
# ['rt', 'live', 'half', 'fascist', 'country', 'corporation', 'long', 'profit', 'keep', 'rolling', 'supreme', 'court', 'taken']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# good morning all~ ☀️
#
# things to remember: you’re capable of greatness, you’re hot, your heart is made of gold and y… https://t.co/hybris3cih
# hashtags : []
# ['good', 'morning', 'thing', 'remember', 'capable', 'greatness', 'hot', 'heart', 'made', 'gold']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @msuppasiteu: snail white is a skin care brand from thailand. it's a simple and sweet skin care collection with a body wash, facial wash…
# hashtags : []
# ['rt', 'snail', 'white', 'skin', 'care', 'brand', 'thailand', 'simple', 'sweet', 'skin', 'care', 'collection', 'body', 'wash', 'facial', 'wash']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i have a brother
# hashtags : []
# ['brother']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @miriam2626: dear greg abbott: as a former assistant da in uvalde i never prosecuted an undocumented person for hurting a child.
# hashtags : []
# ['rt', 'dear', 'greg', 'abbott', 'former', 'assistant', 'da', 'uvalde', 'never', 'prosecuted', 'undocumented', 'person', 'hurting', 'child']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @profkwaah: how can you get a sugar mommy without donating blood? #beachampion 🥱 https://t.co/wkja0gmwcb
# hashtags : ['#beachampion']
# ['rt', 'get', 'sugar', 'mommy', 'without', 'donating', 'blood', 'beachampion']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# the only heaven i'll be sent to is when i'm alone with you.
# hashtags : []
# ['heaven', 'sent', 'alone']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @imrankhanpti: rumours &amp; delib disinfo that a deal has been done. absolutely not! we are moving towards islamabad &amp; no question of any d…
# hashtags : []
# ['rt', 'rumour', 'amp', 'delib', 'disinfo', 'deal', 'done', 'absolutely', 'moving', 'towards', 'islamabad', 'amp', 'question']
# val : (1, 0, 0)   sentiments :  negative
#
#
# the one thing i love abt sims 4: they have pronouns
# hashtags : []
# ['one', 'thing', 'love', 'abt', 'sims', 'pronoun']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @strandjunker: nra blood money
#
# $1,267,139 mitch mcconnell
# $1,269,486 ron johnson
# $1,306,130 marsha blackburn
# $1,968,714 tom cotton
# $2,8…
# hashtags : []
# ['rt', 'nra', 'blood', 'money', 'mitch', 'mcconnell', 'ron', 'johnson', 'marsha', 'blackburn', 'tom', 'cotton']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @cowboyjoseph64: @keeponchucking_ lmao i'm so original! https://t.co/1kmlfdoqbm
# hashtags : []
# ['rt', 'lmao', 'original']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @lafromliny: good morning #horrorfam #mutantfam #horrorcommunity have a terrific #terrortuesday everyone 😘🖤🤘🏻🧟‍♀️🩸💀😈🔪👹🧛‍♀️🍿🎥🧙‍♀️ https:/…
# hashtags : ['#horrorfam', '#mutantfam', '#horrorcommunity', '#terrortuesday']
# ['rt', 'good', 'morning', 'horrorfam', 'mutantfam', 'horrorcommunity', 'terrific', 'terrortuesday', 'everyone', 'http']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @benjochurchill consciousness is generated from ego death-  ego distorts reality so when one has
# an ego death, th… https://t.co/iuer2xznnp
# hashtags : []
# ['consciousness', 'generated', 'ego', 'death', 'ego', 'distorts', 'reality', 'one', 'ego', 'death', 'th']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @mobrooks if you have not received a subpoena, who got it? easy to say i haven’t received one if someone is holding it for you.
# hashtags : []
# ['received', 'subpoena', 'got', 'easy', 'say', 'received', 'one', 'someone', 'holding']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @rahulgandhi: live: congress president smt. sonia gandhi ji’s address | nav sankalp chintan shivir | udaipur | rajasthan https://t.co/rz…
# hashtags : []
# ['rt', 'live', 'congress', 'president', 'smt', 'sonia', 'gandhi', 'ji', 'address', 'nav', 'sankalp', 'chintan', 'shivir', 'udaipur', 'rajasthan']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @danielhampton_3: a britney. not a girl, not yet a woman.
# hashtags : []
# ['rt', 'britney', 'girl', 'yet', 'woman']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @sugoisierra: but look at the onigiri i made!! 🙂🍙 https://t.co/hxmqdew5so
# hashtags : []
# ['rt', 'look', 'onigiri', 'made']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @jeminaclaven @fajouls @jbodywork @cernovich @aoc it's illegal for that 18-year-old to walk in to a store and buy a… https://t.co/eufqtzowgk
# hashtags : []
# ['illegal', 'year', 'old', 'walk', 'store', 'buy']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @fuhknjo: my tia did not make it, she sacrificed herself protecting the kids in her classroom, i beg of you to keep my family including…
# hashtags : []
# ['rt', 'tia', 'make', 'sacrificed', 'protecting', 'kid', 'classroom', 'beg', 'keep', 'family', 'including']
# val : (0, 1, 0)   sentiments :  neutral
# i know this ain’t a real person . . . this a cpu cause wtf 🤮🤮
# hashtags : []
# ['know', 'real', 'person', 'cpu', 'cause', 'wtf']
# val : (1, 0, 0)   sentiments :  negative
#
#
# your thoughts are 💯 correct
# hashtags : []
# ['thought', 'correct']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ah_talukdar9: "loving someone means u can't imagine his/her absence"
#
# good afternoon twitter ❣️ https://t.co/kpkl8q6s6u
# hashtags : []
# ['rt', 'talukdar', 'loving', 'someone', 'mean', 'u', 'imagine', 'absence', 'good', 'afternoon', 'twitter']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @maajidnawaz: the day my comprehensive online suffocation ends is the day you can safely say that we are turning a corner in this ideolo…
# hashtags : []
# ['rt', 'day', 'comprehensive', 'online', 'suffocation', 'end', 'day', 'safely', 'say', 'turning', 'corner', 'ideolo']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @theothermandela: every day that passes without marijuana legalization in wisconsin is a day that injustices go uncorrected and our econ…
# hashtags : []
# ['rt', 'every', 'day', 'pass', 'without', 'marijuana', 'legalization', 'wisconsin', 'day', 'injustice', 'go', 'uncorrected', 'econ']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i’m afraid of falling and losing my teeth. like not breaking bones but losing my teeth😭😭
# hashtags : []
# ['afraid', 'falling', 'losing', 'teeth', 'like', 'breaking', 'bone', 'losing', 'teeth']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @bree1914 @x4eileen @bfes56 @7mcae @keith0sta @goldisez @rdrhwke @de2us @teej2021 @elissa4r @indymagz @b98arnold… https://t.co/adezdvfdne
# hashtags : []
# []
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @tzujuliee: is there really a high chance that this album will debut in bb200 ?
# hashtags : []
# ['rt', 'really', 'high', 'chance', 'album', 'debut', 'bb']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @princenechecfr: office wey them dey run with nepa bill, e reach peter obi turn him go carry the whole university come.
#
# a very intimida…
# hashtags : []
# ['rt', 'office', 'wey', 'dey', 'run', 'nepa', 'bill', 'e', 'reach', 'peter', 'obi', 'turn', 'go', 'carry', 'whole', 'university', 'come', 'intimida']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @uthings_market: 📣 the biggest multi-metaverse giveaway ever!
#
# we have partnered with 15+ web3 projects to giveaway a massive $20,000…
# hashtags : []
# ['rt', 'market', 'biggest', 'multi', 'metaverse', 'giveaway', 'ever', 'partnered', 'web', 'project', 'giveaway', 'massive']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @philipvalentin2: peter obi payed by late parents gratuity and from that proceeds i graduated from university, i have every reason to ca…
# hashtags : []
# ['rt', 'peter', 'obi', 'payed', 'late', 'parent', 'gratuity', 'proceeds', 'graduated', 'university', 'every', 'reason', 'ca']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @j0hnnycdpp: when miss heard plays word games with mr depp about ‘oh i didn’t punch you, i just hit you’ imagine if the shoe were on the…
# hashtags : []
# ['rt', 'miss', 'heard', 'play', 'word', 'game', 'mr', 'depp', 'oh', 'punch', 'hit', 'imagine', 'shoe']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @maggieastor: after sandy hook, i read about how the group of parents waiting in a firehouse had dwindled until finally they were told t…
# hashtags : []
# ['rt', 'sandy', 'hook', 'read', 'group', 'parent', 'waiting', 'firehouse', 'dwindled', 'finally', 'told']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @ladyroza_001 lolz... artist of the year, album of the year, afrobeat artist of the year... still more than damido… https://t.co/gh3hmjsiev
# hashtags : []
# ['lolz', 'artist', 'year', 'album', 'year', 'afrobeat', 'artist', 'year', 'still', 'damido']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @malecslahey: “remember when i said i forgive you? i lied.”
# hashtags : []
# ['rt', 'remember', 'said', 'forgive', 'lied']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @mainlyforbellem @fiona4736fiona are we finally getting a kissing scene in episode 6? abangan mamaya, 8pm on iwantt… https://t.co/2erb2faoij
# hashtags : []
# ['finally', 'getting', 'kissing', 'scene', 'episode', 'abangan', 'mamaya', 'pm', 'iwantt']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @rcstweets: 3.3 'deep dive (pause) uncoiling memory' is a new exhibition by alberta whittle that features film, sculpture, tapestry and…
# hashtags : []
# ['rt', 'deep', 'dive', 'pause', 'uncoiling', 'memory', 'new', 'exhibition', 'alberta', 'whittle', 'feature', 'film', 'sculpture', 'tapestry']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i’d love ❤️ a neighbor like her ..
# hashtags : []
# ['love', 'neighbor', 'like']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @exilkat: some old doodles
# full🔞: https://t.co/xwnb7cvsof https://t.co/vowjbfrtcv
# hashtags : []
# ['rt', 'old', 'doodle', 'full']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @fayepjm: no one gets it like i do https://t.co/batoon0qgt
# hashtags : []
# ['rt', 'one', 'get', 'like']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @unite2defend: don’t be a matthew‼️⤵️🤦‍♀️🙄 https://t.co/zlpsdc2csu
# hashtags : []
# ['rt', 'matthew']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @vp: enough is enough. as a nation, we must have the courage to take action and prevent this from ever happening again. it is long past…
# hashtags : []
# ['rt', 'enough', 'enough', 'nation', 'must', 'courage', 'take', 'action', 'prevent', 'ever', 'happening', 'long', 'past']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @danyellemizpah: i'll be giving out free packs of cereal to few lucky people within uyo city/akwa ibom state... please if you're outside…
# hashtags : []
# ['rt', 'giving', 'free', 'pack', 'cereal', 'lucky', 'people', 'within', 'uyo', 'city', 'akwa', 'ibom', 'state', 'please', 'outside']
# val : (0, 0, 1)   sentiments :  positive
#
#
# #gospelradiopromoad for immediate release: watch and pray the sophomore release by phy-turs for christ do yourself… https://t.co/axc4d17kv5
# hashtags : ['#gospelradiopromoad']
# ['gospelradiopromoad', 'immediate', 'release', 'watch', 'pray', 'sophomore', 'release', 'phy', 'turs', 'christ']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @marrvi_v: @streamfortaejp @bts_twt we purple you taehyung
# always with you taehyung
#
# i always listen to #v_christmastree #christmastree…
# hashtags : ['#v_christmastree', '#christmastree']
# ['rt', 'v', 'twt', 'purple', 'taehyung', 'always', 'taehyung', 'always', 'listen', 'v', 'christmastree', 'christmastree']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @cjad800: bill 96 is 'the most gratuitous use of power i've ever seen,' said lawyer julius grey as he unveiled the plan by a committee o…
# hashtags : []
# ['rt', 'bill', 'gratuitous', 'use', 'power', 'ever', 'seen', 'said', 'lawyer', 'julius', 'grey', 'unveiled', 'plan', 'committee']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @_wrevolution_: "some of you may die... but it is a sacrifice i'm willing to make"
#
# #suegrayreport https://t.co/m052q4whip
# hashtags : ['#suegrayreport']
# ['rt', 'wrevolution', 'may', 'die', 'sacrifice', 'willing', 'make', 'suegrayreport']
# val : (0, 0, 1)   sentiments :  positive
#
#
#
#
# rt @pippacrerar: cab off leaving do on 18 june 2020 ended up in simon case's offices where staff brought pizza and prosecco.
#
# depy cab sec…
# hashtags : []
# ['rt', 'cab', 'leaving', 'june', 'ended', 'simon', 'case', 'office', 'staff', 'brought', 'pizza', 'prosecco', 'depy', 'cab', 'sec']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @drlizzieskinner: when you don’t want foetuses aborted but you accept children being shot dead in school you have a serious problem.
# hashtags : []
# ['rt', 'want', 'foetus', 'aborted', 'accept', 'child', 'shot', 'dead', 'school', 'serious', 'problem']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @newsmax these loser trumpers i swear, lock trump up
# hashtags : []
# ['loser', 'trumpers', 'swear', 'lock', 'trump']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @employablesoff: 👀 first 1000 get a dm
#
# 🤗 tag a friend so he doesn't miss it https://t.co/ma7ynmpetz
# hashtags : []
# ['rt', 'first', 'get', 'dm', 'tag', 'friend', 'miss']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @fartycheddarcat unfortunately, no one can understand y these things happen my sweet cheddy. they have no respect f… https://t.co/hpeeeotsdo
# hashtags : []
# ['unfortunately', 'one', 'understand', 'thing', 'happen', 'sweet', 'cheddy', 'respect', 'f']
# val : (0, 0, 1)   sentiments :  positive
# @elkehol oi, i’m still young!
# hashtags : []
# ['oi', 'still', 'young']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @bloom_forge if you talk to me in person and if i get to know you on a personal basis i'll use any personal names y… https://t.co/md2l6zvolh
# hashtags : []
# ['forge', 'talk', 'person', 'get', 'know', 'personal', 'basis', 'use', 'personal', 'name']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @chiefrocka77 definitely a fail on his community, but i respect this young gentlemen not only for who he is but als… https://t.co/3ihkutzhwg
# hashtags : []
# ['definitely', 'fail', 'community', 'respect', 'young', 'gentleman', 'al']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @rtbinfo @seanfalvey1983 i’m also asking for assistance please… begging at this stage
# hashtags : []
# ['also', 'asking', 'assistance', 'please', 'begging', 'stage']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @fred_guttenberg: i sat with you 3 years ago.  i begged you to have a different response to gun violence.  you went forward from there &amp;…
# hashtags : []
# ['rt', 'guttenberg', 'sat', 'year', 'ago', 'begged', 'different', 'response', 'gun', 'violence', 'went', 'forward', 'amp']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @kaleyroxyoursox @richyputsinwork @nataliereporter how you register a gun or get a license also varies drastically from state to state
# hashtags : []
# ['register', 'gun', 'get', 'license', 'also', 'varies', 'drastically', 'state', 'state']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @kathapatan: appreciation post to vice president leni robredo — the game changer, champion of good governance, a living example of "wome…
# hashtags : []
# ['rt', 'appreciation', 'post', 'vice', 'president', 'leni', 'robredo', 'game', 'changer', 'champion', 'good', 'governance', 'living', 'example', 'wome']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i have 20 students.  i wonder which one would have lived?
#
# i don’t have answers and i certainly don’t want you fuc… https://t.co/lvepkawjly
# hashtags : []
# ['student', 'wonder', 'one', 'would', 'lived', 'answer', 'certainly', 'want', 'fuc']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @redizak: you think i am bold and self confident, but truth is i'm opposite... i wanna thank my home town, my family and my ex for huge…
# hashtags : []
# ['rt', 'think', 'bold', 'self', 'confident', 'truth', 'opposite', 'wan', 'na', 'thank', 'home', 'town', 'family', 'ex', 'huge']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @kraypex tbh i didn't notice the mark😂
# hashtags : []
# ['tbh', 'notice', 'mark']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# although eu commission chief von der leyen admits she doesn't believe a deal on the next package of #russia sanctio… https://t.co/grjqbrcmpc
# hashtags : ['#russia']
# ['although', 'eu', 'commission', 'chief', 'von', 'der', 'leyen', 'admits', 'believe', 'deal', 'next', 'package', 'russia', 'sanctio']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @only8starever i could stare at his eyes for days.
# hashtags : []
# ['could', 'stare', 'eye', 'day']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @muftimenk: everyone’s journey is different. don’t look at someone and make your own assumptions because there  are many who are silentl…
# hashtags : []
# ['rt', 'everyone', 'journey', 'different', 'look', 'someone', 'make', 'assumption', 'many', 'silentl']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @pentsirrr: this is why the bad bitches are marrying every weekend and sister mary is going for her 10th shiloh conference at 37
# hashtags : []
# ['rt', 'bad', 'bitch', 'marrying', 'every', 'weekend', 'sister', 'mary', 'going', 'th', 'shiloh', 'conference']
# val : (1, 0, 0)   sentiments :  negative
#
#
# i've seen way worse stuff on twitter than i've seen on 4chan tbh
# hashtags : []
# ['seen', 'way', 'worse', 'stuff', 'twitter', 'seen', 'chan', 'tbh']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @breitbartnews: a growing share of americans wants immigration levels to be reduced, according to a new poll. https://t.co/ngw9wuvlw9
# hashtags : []
# ['rt', 'growing', 'share', 'american', 'want', 'immigration', 'level', 'reduced', 'according', 'new', 'poll']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @dsapangbato2: [trailer] kuya (2022)
#
# 🌸a beautiful story about reunited "brothers" and their first night together as adults. 🌸
#
# a colla…
# hashtags : []
# ['rt', 'trailer', 'kuya', 'beautiful', 'story', 'reunited', 'brother', 'first', 'night', 'together', 'adult', 'colla']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @biairwaidorf_: i love you both so much, mr and mrs ford. 🥰 https://t.co/89mukfjbiw
# hashtags : []
# ['rt', 'love', 'much', 'mr', 'mr', 'ford']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @hakeembahari: working in kl/selangor is no longer a thing to be proud of.
#
# you are spending 2-4 hours of your day in your car. if you h…
# hashtags : []
# ['rt', 'working', 'kl', 'selangor', 'longer', 'thing', 'proud', 'spending', 'hour', 'day', 'car', 'h']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @yaraho6: vayamos por la 4ta semana!!!
# vamos team jimin
#
# we love you jimin
#
# i feel like the sun shines a little brighter when i listen…
# hashtags : []
# ['rt', 'vayamos', 'por', 'la', 'ta', 'semana', 'vamos', 'team', 'jimin', 'love', 'jimin', 'feel', 'like', 'sun', 'shine', 'little', 'brighter', 'listen']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @john_kaufman: jeebus, the shooter was using .556 ammo. those rounds are huge, literally the size of aa batteries. how does a 19 year ol…
# hashtags : []
# ['rt', 'kaufman', 'jeebus', 'shooter', 'using', 'ammo', 'round', 'huge', 'literally', 'size', 'aa', 'battery', 'year', 'ol']
# val : (0, 0, 1)   sentiments :  positive
#
#
# wanted
# reword : 10 k€
# hashtags : []
# ['wanted', 'reword', 'k']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# transforming the might draw, a row of shaky squares
# ؟?
# سےفے نمشے https://t.co/nvwrkvgfrh
# hashtags : []
# ['transforming', 'might', 'draw', 'row', 'shaky', 'square']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @jitinprasada: how’s the “prasad” mr. sibal ! 😊
# #rajyasabha
# @kapilsibal
# hashtags : ['#rajyasabha']
# ['rt', 'prasad', 'mr', 'sibal', 'rajyasabha']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @sosuzay: when i die dont photoshop me next to clouds put me next to chief keef
# hashtags : []
# ['rt', 'die', 'dont', 'photoshop', 'next', 'cloud', 'put', 'next', 'chief', 'keef']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @kmroyais: jungkook made a joke and the first thing he did was checking out jimin's reaction. he is always so aware of jimin's presence.…
# hashtags : []
# ['rt', 'jungkook', 'made', 'joke', 'first', 'thing', 'checking', 'jimin', 'reaction', 'always', 'aware', 'jimin', 'presence']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @longwall26: when a small group protested outside a supreme court justice’s house, the senate took action within twenty-four hours. you…
# hashtags : []
# ['rt', 'small', 'group', 'protested', 'outside', 'supreme', 'court', 'justice', 'house', 'senate', 'took', 'action', 'within', 'twenty', 'four', 'hour']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @r_mor: if she can go to batasan, she can go to bilibid. #imeldaiselda
# hashtags : ['#imeldaiselda']
# ['rt', 'mor', 'go', 'batasan', 'go', 'bilibid', 'imeldaiselda']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# never know wizzy was am it expert.   now i've got to sort it https://t.co/owcd9zf4zq
# hashtags : []
# ['never', 'know', 'wizzy', 'expert', 'got', 'sort']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @bria_titania: g - get
# r - rid
# o - of old
# w - ways
# hashtags : []
# ['rt', 'titania', 'g', 'get', 'r', 'rid', 'old', 'w', 'way']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @davidhogg111: no parent should drop their kid off at school and then need a dna test to id which child is their child because they have…
# hashtags : []
# ['rt', 'parent', 'drop', 'kid', 'school', 'need', 'dna', 'test', 'id', 'child', 'child']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# barcelona vs a league
# live streaming hd🇦🇴
# #epl #efootball
# #laliga #barcelona
# #barca
#
# #barcelona vs #aleague
#
# live s… https://t.co/qnyeuadsgl
# hashtags : ['#epl', '#efootball', '#laliga', '#barcelona', '#barca', '#barcelona', '#aleague']
# ['barcelona', 'v', 'league', 'live', 'streaming', 'hd', 'epl', 'efootball', 'laliga', 'barcelona', 'barca', 'barcelona', 'v', 'aleague', 'live']
# val : (0, 0, 1)   sentiments :  positive
# rt @gummy_sooyaaa: dior is under lvmh group and cartier is under richemont group, both house is sworn enemies when it comes to sales, reput…
# hashtags : []
# ['rt', 'sooyaaa', 'dior', 'lvmh', 'group', 'cartier', 'richemont', 'group', 'house', 'sworn', 'enemy', 'come', 'sale', 'reput']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @lewinskl: there is only one davido, there will never be a duplicate.
# hashtags : []
# ['rt', 'one', 'davido', 'never', 'duplicate']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# also...you should change the way you speak. could you not speak more like me, with a refined and elegant tone?
# hashtags : []
# ['also', 'change', 'way', 'speak', 'could', 'speak', 'like', 'refined', 'elegant', 'tone']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @yourswithluv: oh hello, maybe its fate that i appeared on your timeline today but there's a chance we'll never meet again so please ope…
# hashtags : []
# ['rt', 'oh', 'hello', 'maybe', 'fate', 'appeared', 'timeline', 'today', 'chance', 'never', 'meet', 'please', 'ope']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @potus: as a nation we must ask: when in god’s name will we stand up to the gun lobby?
#
# when in god’s name will we do what needs to be d…
# hashtags : []
# ['rt', 'nation', 'must', 'ask', 'god', 'name', 'stand', 'gun', 'lobby', 'god', 'name', 'need']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @kayiluiz: ꒰ #mixxiw #มิกซิวคุยคนเดียวทําไมเอ่ย ꒱
#
# perfect sound effects💯 i’m dying https://t.co/eyppj6djv3
# hashtags : ['#mixxiw']
# ['rt', 'mixxiw', 'perfect', 'sound', 'effect', 'dying']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @glnnlopez: voting marcos over robredo, padilla over diokno, tulfo over trillanes or estrada over de lima is the most extreme idiocy a f…
# hashtags : []
# ['rt', 'voting', 'marcos', 'robredo', 'padilla', 'diokno', 'tulfo', 'trillanes', 'estrada', 'de', 'lima', 'extreme', 'idiocy', 'f']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @ctvnews biden the criminal. no thanks. americans have guns for an obvious reason and the fbi let tragic events hap… https://t.co/aiatphejm5
# hashtags : []
# ['biden', 'criminal', 'thanks', 'american', 'gun', 'obvious', 'reason', 'fbi', 'let', 'tragic', 'event', 'hap']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @weversetrsr: [treasure weverse] 20220525
# #yoshi post 🌟
#
# 🐯: when i got home hyunsuk hyung gave me a surprise gift. ahh i love it, its th…
# hashtags : ['#yoshi']
# ['rt', 'treasure', 'weverse', 'yoshi', 'post', 'got', 'home', 'hyunsuk', 'hyung', 'gave', 'surprise', 'gift', 'ahh', 'love', 'th']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @jmjm_131013: @starnewskorea we love you jimin
#
# i can't stop playing the trending song #withyou by #jimin #btsjimin of #bts (@bts_twt)…
# hashtags : ['#withyou', '#jimin', '#btsjimin', '#bts']
# ['rt', 'love', 'jimin', 'stop', 'playing', 'trending', 'song', 'withyou', 'jimin', 'btsjimin', 'bts', 'twt']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @adamrmcvey and the gravy bus comes to a halt. no wonder you’re furious at democracy in action
# hashtags : []
# ['gravy', 'bus', 'come', 'halt', 'wonder', 'furious', 'democracy', 'action']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @slukako: i was seated in my corner. you guys came disturbing me to talk about 1person killed in north nigeria. today,you want me silent…
# hashtags : []
# ['rt', 'seated', 'corner', 'guy', 'came', 'disturbing', 'talk', 'person', 'killed', 'north', 'nigeria', 'today', 'want', 'silent']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @ukraine_world: russia wants to exchange the grain export corridor for lifting sanctions, reports 🇷🇺 propaganda media tass. this is a di…
# hashtags : []
# ['rt', 'world', 'russia', 'want', 'exchange', 'grain', 'export', 'corridor', 'lifting', 'sanction', 'report', 'propaganda', 'medium', 'ta', 'di']
# val : (0, 0, 1)   sentiments :  positive
#
#
#
#
# rt @sqzbiotech: sqz’s r&amp;d investor event last week highlighted our poc manufacturing system, celiac program, ruo system collaboration w/@st…
# hashtags : []
# ['rt', 'sqz', 'r', 'amp', 'investor', 'event', 'last', 'week', 'highlighted', 'poc', 'manufacturing', 'system', 'celiac', 'program', 'ruo', 'system', 'collaboration', 'w']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ghostpeachh_: may i have this dance? #sashanne #sashawaybright #anneboonchuy https://t.co/ka086sipzd
# hashtags : ['#sashanne', '#sashawaybright', '#anneboonchuy']
# ['rt', 'may', 'dance', 'sashanne', 'sashawaybright', 'anneboonchuy']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @chunkymark: a fucking karaoke machine, this is an absolute joke boris johnson “there was no party” #pmqs
# hashtags : ['#pmqs']
# ['rt', 'fucking', 'karaoke', 'machine', 'absolute', 'joke', 'boris', 'johnson', 'party', 'pmqs']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @hzoruafact @pokianne__ oh, perhaps i’m the idiot then. i take that back, you got a good eye. yeah, unless this is… https://t.co/bcpbudtocp
# hashtags : []
# ['oh', 'perhaps', 'idiot', 'take', 'back', 'got', 'good', 'eye', 'yeah', 'unless']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# going the fuck to bed bc csp just crashed and lost progress i saved idk how thats even possible lmao
# hashtags : []
# ['going', 'fuck', 'bed', 'bc', 'csp', 'crashed', 'lost', 'progress', 'saved', 'idk', 'thats', 'even', 'possible', 'lmao']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @kubalazila: i’m following whoever follows me in 2 secs now!!!🍑🦐🦑🍏💦
# hashtags : []
# ['rt', 'following', 'whoever', 'follows', 'sec']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @jrfromstrickley: over the past 15mth, i’ve struggled with my mental health, so i now walk the cows in for milking, rather than sitting…
# hashtags : []
# ['rt', 'past', 'mth', 'struggled', 'mental', 'health', 'walk', 'cow', 'milking', 'rather', 'sitting']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @rosamundi: i can only assume that the one who left on their own at 0420 had got so drunk that they were just left in the garden to sobe…
# hashtags : []
# ['rt', 'assume', 'one', 'left', 'got', 'drunk', 'left', 'garden', 'sobe']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i want everyone to eat, just not at my table.
# hashtags : []
# ['want', 'everyone', 'eat', 'table']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# babies.
# hashtags : []
# ['baby']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @_doybeth: if nobody is cheering you on, god and the cloud of witnesses are cheering you on!!!
# keep goinggggggg!!!!!
#
# #wordbyps
# #weareth…
# hashtags : ['#wordbyps', '#weareth']
# ['rt', 'doybeth', 'nobody', 'cheering', 'god', 'cloud', 'witness', 'cheering', 'keep', 'goinggggggg', 'wordbyps', 'weareth']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @deerahahaha: i may look normal but i want a pre wedding photoshoot like this https://t.co/k7uof37crq
# hashtags : []
# ['rt', 'may', 'look', 'normal', 'want', 'pre', 'wedding', 'photoshoot', 'like']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @johnmalcom18: covid still active in ns ,why i wear a mask in public
# hashtags : []
# ['rt', 'covid', 'still', 'active', 'n', 'wear', 'mask', 'public']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @flashyasf: im ok with being alone long as i got money
# hashtags : []
# ['rt', 'im', 'ok', 'alone', 'long', 'got', 'money']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @jimichooz: @knjgioss somebody needs to make a vid of all the synchronicitys they've had throughout their career cause what the hell
# hashtags : []
# ['rt', 'somebody', 'need', 'make', 'vid', 'synchronicity', 'throughout', 'career', 'cause', 'hell']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @maaassssaaa i suggest you contact jameslucastech on ig at +1(802) 379-9165 on whatsapp he's a professional in hand… https://t.co/mh1intidqd
# hashtags : []
# ['suggest', 'contact', 'jameslucastech', 'ig', 'whatsapp', 'professional', 'hand']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @texastribune: uvalde parents huddled close to their relatives tuesday outside the city’s civic center, where they waited for hours to l…
# hashtags : []
# ['rt', 'uvalde', 'parent', 'huddled', 'close', 'relative', 'tuesday', 'outside', 'city', 'civic', 'center', 'waited', 'hour', 'l']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @blackproudman: can i get some neck? https://t.co/5jn5yolb6e https://t.co/1pffaafor0
# hashtags : []
# ['rt', 'get', 'neck']
# val : (0, 1, 0)   sentiments :  neutral
# we have had a wonderful team morning today creating artwork from different commonwealth countries. the children hav… https://t.co/bxsg0ixtla
# hashtags : []
# ['wonderful', 'team', 'morning', 'today', 'creating', 'artwork', 'different', 'commonwealth', 'country', 'child', 'hav']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @vinyl404 aha i joined i'm emily 👍👍👍
# hashtags : []
# ['aha', 'joined', 'emily']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @tbillz75 @secupp could you imagine a person suffering from a mental breakdown with violent thoughts without acces to a powerful gun?
# hashtags : []
# ['could', 'imagine', 'person', 'suffering', 'mental', 'breakdown', 'violent', 'thought', 'without', 'acces', 'powerful', 'gun']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @la_greatke: uliza kiatu wasn't just a song
# hashtags : []
# ['rt', 'greatke', 'uliza', 'kiatu', 'song']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# stan twitter never have i ever:
#
# 1. never
# 2. never
# 3. never
# 4. never
# 5. never
# 6. i have
# 7. never
# 8. never
# 9. hmm...… https://t.co/zbyfsngoc7
# hashtags : []
# ['stan', 'twitter', 'never', 'ever', 'never', 'never', 'never', 'never', 'never', 'never', 'never', 'hmm']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @bambam1a: @jaybnow_hr i'm proud of you https://t.co/6ue4zmhceb
# hashtags : []
# ['rt', 'hr', 'proud']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @mikeluhg2: some of the stuff this fella came out with 💀 we can laugh now but fucking hell.  we survived a footballing apocalypse.
#
# ho…
# hashtags : []
# ['rt', 'stuff', 'fella', 'came', 'laugh', 'fucking', 'hell', 'survived', 'footballing', 'apocalypse', 'ho']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @lovely_maci: i’m really a low maintenance friend. we don’t have to text or talk every day &amp; i still love you the same!
# hashtags : []
# ['rt', 'maci', 'really', 'low', 'maintenance', 'friend', 'text', 'talk', 'every', 'day', 'amp', 'still', 'love']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @kt_so_it_goes: you don’t have to say a word about the second amendment to unequivocally state that gun culture in this country is a gho…
# hashtags : []
# ['rt', 'go', 'say', 'word', 'second', 'amendment', 'unequivocally', 'state', 'gun', 'culture', 'country', 'gho']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# a-league all-stars vs barcelona stream
#
# link 1 🔴https://t.co/gq1qxi6c92
#
# go live 🔴► https://t.co/gq1qxi6c92… https://t.co/jxrlbm1ulv
# hashtags : []
# ['league', 'star', 'v', 'barcelona', 'stream', 'link', 'go', 'live']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @crabhive i do respect reece james highly
# hashtags : []
# ['respect', 'reece', 'james', 'highly']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @httpxellise: "nah, i'll do it tomorrow" is my everyday mood.
# hashtags : []
# ['rt', 'nah', 'tomorrow', 'everyday', 'mood']
# val : (1, 0, 0)   sentiments :  negative
#
#
# wn.
# i didnt even wanna be born in the first place
# hashtags : []
# ['wn', 'didnt', 'even', 'wan', 'na', 'born', 'first', 'place']
# val : (0, 0, 1)   sentiments :  positive
#
#
# it's better to watch a match live in stadium. ☺
# #cleartriptatkaallife https://t.co/ywgws0l3pi
# hashtags : ['#cleartriptatkaallife']
# ['better', 'watch', 'match', 'live', 'stadium', 'cleartriptatkaallife']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @rexchapman: on 18 january 1984, steve kerr’s father - malcom - was shot and killed by two gunmen.
#
# please take a moment. pass it on if…
# hashtags : []
# ['rt', 'january', 'steve', 'kerr', 'father', 'malcom', 'shot', 'killed', 'two', 'gunman', 'please', 'take', 'moment', 'pas']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @madewmoonshine: we had the huge pleasure of having #kun from #wayv swinging by the studio! thanks for a good chat &amp; hope to see you aga…
# hashtags : ['#kun', '#wayv']
# ['rt', 'huge', 'pleasure', 'kun', 'wayv', 'swinging', 'studio', 'thanks', 'good', 'chat', 'amp', 'hope', 'see', 'aga']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @cursedlabs: we’re always busy concocting greatness in our labs. but we always have room for more! hit us up if you have a brilliant ide…
# hashtags : []
# ['rt', 'always', 'busy', 'concocting', 'greatness', 'lab', 'always', 'room', 'hit', 'u', 'brilliant', 'ide']
# val : (0, 0, 1)   sentiments :  positive
#
#
# as we constantly strive to deliver a ‘wow customer experience’ to our clients, acknowledgments like these push us t… https://t.co/dqmeq3wpji
# hashtags : []
# ['constantly', 'strive', 'deliver', 'wow', 'customer', 'experience', 'client', 'acknowledgment', 'like', 'push', 'u']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @ani: prime minister narendra modi will inaugurate 1152 houses constructed as part of the light house project in chennai tomorrow, built…
# hashtags : []
# ['rt', 'prime', 'minister', 'narendra', 'modi', 'inaugurate', 'house', 'constructed', 'part', 'light', 'house', 'project', 'chennai', 'tomorrow', 'built']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @gamaagri: @cub_ietz @cryptojack @paysmarty “we are what we repeatedly do. excellence, then, is not an act, but a habit.”
# — aristotle
#
# 👉…
# hashtags : []
# ['rt', 'ietz', 'repeatedly', 'excellence', 'act', 'habit', 'aristotle']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @satyanveshan: no .
#
# i cried when hindu dharmacharyas and mathadheeshas referred to this rapist mafia as a religion .
# hashtags : []
# ['rt', 'cried', 'hindu', 'dharmacharyas', 'mathadheeshas', 'referred', 'rapist', 'mafia', 'religion']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @theinsiderpaper they recommend wearing a mask 😷 to prevent getting #monkeypox regardless
# hashtags : ['#monkeypox']
# ['recommend', 'wearing', 'mask', 'prevent', 'getting', 'monkeypox', 'regardless']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @afamdeluxo: efcc did a thorough background check on peter obi &amp; found nothing.
# hear him explaining &amp; showing documents of how he acqui…
# hashtags : []
# ['rt', 'efcc', 'thorough', 'background', 'check', 'peter', 'obi', 'amp', 'found', 'nothing', 'hear', 'explaining', 'amp', 'showing', 'document', 'acqui']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @pervsinner @d3vilishfate i need to refresh my memory...bye
# hashtags : []
# ['need', 'refresh', 'memory', 'bye']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# masterful lecture by dr minakshi pathak on "benefits of healing mind - when you need to calm your mind and body."
# h… https://t.co/hhp0c2wksc
# hashtags : []
# ['masterful', 'lecture', 'dr', 'minakshi', 'pathak', 'benefit', 'healing', 'mind', 'need', 'calm', 'mind', 'body', 'h']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @malloryblount: georgia’s next u.s. senator! so proud to be a part of @teamherschel! #gapol https://t.co/tgghrwkejm
# hashtags : ['#gapol']
# ['rt', 'georgia', 'next', 'u', 'senator', 'proud', 'part', 'gapol']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @jahstdaily: i think let's cry together, like who wouldn't be proud🥺😭 keep going love!!!
#
# @sb19official #sb19_justin https://t.co/ocqdyy…
# hashtags : ['#sb19_justin']
# ['rt', 'think', 'let', 'cry', 'together', 'like', 'proud', 'keep', 'going', 'love', 'sb', 'justin']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @mikeluhg2: some of the stuff this fella came out with 💀 we can laugh now but fucking hell.  we survived a footballing apocalypse.
#
# ho…
# hashtags : []
# ['rt', 'stuff', 'fella', 'came', 'laugh', 'fucking', 'hell', 'survived', 'footballing', 'apocalypse', 'ho']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @naba83444801: now it's over...
# i request everyone to study hard.
# possibility of cancellation is very lower thn we thought.
# but @thetrut…
# hashtags : []
# ['rt', 'request', 'everyone', 'study', 'hard', 'possibility', 'cancellation', 'lower', 'thn', 'thought']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @valdemings: marco rubio has some nerve to attack me for “bragging” about my public service. he has no clue what it’s like to work in la…
# hashtags : []
# ['rt', 'marco', 'rubio', 'nerve', 'attack', 'bragging', 'public', 'service', 'clue', 'like', 'work', 'la']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @nleohrs i bought mine from an indo seller sa shopee ☺️ https://t.co/vmg2id3vya
# hashtags : []
# ['bought', 'mine', 'indo', 'seller', 'sa', 'shopee']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @nicolledwallace: i can’t stop watching this
# hashtags : []
# ['rt', 'stop', 'watching']
# val : (0, 1, 0)   sentiments :  neutral
# rt @shireenmazari1: fake news. no question of any deal we will not leave till election &amp; dissolution of assemblies dates r given. @official…
# hashtags : []
# ['rt', 'fake', 'news', 'question', 'deal', 'leave', 'till', 'election', 'amp', 'dissolution', 'assembly', 'date', 'r', 'given']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @bonifasko: i'm really  ̸h̸o̸r̸n̸y̸  hungry🍳 https://t.co/acjlh17amk
# hashtags : []
# ['rt', 'really', 'h', 'r', 'n', 'hungry']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @marktuan: its been a while thailand! see you guys soon💜 https://t.co/uypjvzoi09
# hashtags : []
# ['rt', 'thailand', 'see', 'guy', 'soon']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# we purple you taehyung
# always with you taehyung
#
# i'm always listening to this amazing ost #christmastree by #v of… https://t.co/lktvrad7if
# hashtags : ['#christmastree', '#v']
# ['purple', 'taehyung', 'always', 'taehyung', 'always', 'listening', 'amazing', 'ost', 'christmastree', 'v']
# val : (0, 0, 1)   sentiments :  positive
#
#
# masses are not interested in knowing the ins and outs of a concept or an idea. tell them a recipe, tell them 5 hack… https://t.co/9wy8ed8dul
# hashtags : []
# ['mass', 'interested', 'knowing', 'in', 'out', 'concept', 'idea', 'tell', 'recipe', 'tell', 'hack']
# val : (1, 0, 0)   sentiments :  negative
#
#
# sir we just have a one attempt per year so we want utilize it properly! there is no gap between board exams and nee… https://t.co/urulrtsf2i
# hashtags : []
# ['sir', 'one', 'attempt', 'per', 'year', 'want', 'utilize', 'properly', 'gap', 'board', 'exam', 'nee']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @kylee_marchant @mikecwright i love sports, i watch sports more than anything else but when it comes to innocent pe… https://t.co/hvoaxwuz2p
# hashtags : []
# ['marchant', 'love', 'sport', 'watch', 'sport', 'anything', 'else', 'come', 'innocent', 'pe']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @francis_scarr: russian defence ministry: this morning we successfully launched missiles at a military aviation engine factory in zapori…
# hashtags : []
# ['rt', 'scarr', 'russian', 'defence', 'ministry', 'morning', 'successfully', 'launched', 'missile', 'military', 'aviation', 'engine', 'factory', 'zapori']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @cityreportben: klopp didn't win a single game against the top four, spent less time at the summit than spurs, didn't win the league but…
# hashtags : []
# ['rt', 'klopp', 'win', 'single', 'game', 'top', 'four', 'spent', 'le', 'time', 'summit', 'spur', 'win', 'league']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @writerjac: sorry tech issue - had to retweet my tweet - have saved everyone lovely one of you already retweeted! to celebrate getting f…
# hashtags : []
# ['rt', 'sorry', 'tech', 'issue', 'retweet', 'tweet', 'saved', 'everyone', 'lovely', 'one', 'already', 'retweeted', 'celebrate', 'getting', 'f']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @ebuka: "i'm assuring nigerians that peter obi will be on the presidential ballot in 2023." -doyin okupe
# hashtags : []
# ['rt', 'assuring', 'nigerian', 'peter', 'obi', 'presidential', 'ballot', 'doyin', 'okupe']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @traviscravey: 11y saw me crying and asked if it was about uvalde.
#
# “yeah,” i said. “it’s really sad and i worry about y’all.”
#
# “it’s o…
# hashtags : []
# ['rt', 'saw', 'cry', 'asked', 'uvalde', 'yeah', 'said', 'really', 'sad', 'worry']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @piperlovieee: ‘we fight for our music. yeah, that’s bts. never-ending forever, baby!’
#
# how i love them and their music.😌💜
#
# #yettocome b…
# hashtags : ['#yettocome']
# ['rt', 'fight', 'music', 'yeah', 'bts', 'never', 'ending', 'forever', 'baby', 'love', 'music', 'yettocome', 'b']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @pierrekory: hey @elonmusk, can you help a brother out? twitter has blocked all new followers on my account for 2 months now (except for…
# hashtags : []
# ['rt', 'hey', 'help', 'brother', 'twitter', 'blocked', 'new', 'follower', 'account', 'month', 'except']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @lia_shiya @leaveerwinalone true, and agree 100%. there needs to be a good balance.
# hashtags : []
# ['shiya', 'true', 'agree', 'need', 'good', 'balance']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @dannagal: australia👇
# hashtags : []
# ['rt', 'australia']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i loove the mv outfits they wore for todays fansign i wish we would have seen them more
# hashtags : []
# ['loove', 'mv', 'outfit', 'wore', 'today', 'fansign', 'wish', 'would', 'seen']
# val : (0, 0, 1)   sentiments :  positive
#
#
# the only thing that stops a bad guy with a gun is voters with an attention span longer than a fruit fly, politician… https://t.co/me3e2c4s0a
# hashtags : []
# ['thing', 'stop', 'bad', 'guy', 'gun', 'voter', 'attention', 'span', 'longer', 'fruit', 'fly', 'politician']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @brown_nemesis i'll keep the fingers crossed for you and your little one. i am sure, everything will be fine.
# hashtags : []
# ['nemesis', 'keep', 'finger', 'crossed', 'little', 'one', 'sure', 'everything', 'fine']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @anneapplebaum i don't understand why it even needs to be a discussion. they should have been deployed and used already
# hashtags : []
# ['understand', 'even', 'need', 'discussion', 'deployed', 'used', 'already']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @arsenaln7: 🇧🇷 tite on which england player he would cap for brazil: i would go for saka. i like lean, fast players. and he is the type…
# hashtags : []
# ['rt', 'tite', 'england', 'player', 'would', 'cap', 'brazil', 'would', 'go', 'saka', 'like', 'lean', 'fast', 'player', 'type']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @theboyzfolder: #theboyz departure to l.a to start their the b zone world tour
#
# #더보이즈 @we_the_boyz @ist_theboyz https://t.co/f6nx44zee8
# hashtags : ['#theboyz']
# ['rt', 'theboyz', 'departure', 'l', 'start', 'b', 'zone', 'world', 'tour', 'boyz', 'theboyz']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @shxx131bi131: thank you for carefully listening to my story🙏 @_xtgx
# hashtags : []
# ['rt', 'thank', 'carefully', 'listening', 'story', 'xtgx']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @gaialect: i can assure you though, i'm not trying to be fake nice to anyone. i genuinely do fear hurting people's feelings unintentiona…
# hashtags : []
# ...
# hashtags : []
# ['watched', 'snatch', 'game', 'th', 'time', 'yes', 'yes']
# val : (1, 0, 0)   sentiments :  negative
# @obkatiekat @gladd remind new of d1 armor. i fuck with it.
# hashtags : []
# ['remind', 'new', 'armor', 'fuck']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @kamotachi: this is my game in development! kinnkuneko: super muscle cat ‼️‼️ 🐱💪
#
# rt helps a lot to make the game known ! 🙏
# #gamedev #in…
# hashtags : ['#gamedev', '#in']
# ['rt', 'game', 'development', 'kinnkuneko', 'super', 'muscle', 'cat', 'rt', 'help', 'lot', 'make', 'game', 'known', 'gamedev']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @pinesoul69: ugh its monday.. who needs a yummy snack?? 😋 https://t.co/arpamky3pr
# hashtags : []
# ['rt', 'ugh', 'monday', 'need', 'yummy', 'snack']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @bblock29 @realtuckfrumper nope. they keep trying to reach lower and lower. is there a bottom?
# hashtags : []
# ['nope', 'keep', 'trying', 'reach', 'lower', 'lower', 'bottom']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# 📍 new listing 📍 take a look at this fantastic new property that just hit the market located at 2630 sw 28th st 44 i… https://t.co/jiokj9l391
# hashtags : []
# ['new', 'listing', 'take', 'look', 'fantastic', 'new', 'property', 'hit', 'market', 'located', 'sw', 'th', 'st']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i will not stand for this.
# hashtags : []
# ['stand']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# every once in a while i do wish you miraculously pop up in my message.
# hashtags : []
# ['every', 'wish', 'miraculously', 'pop', 'message']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @dinachka82: actually, there is something we can do. every person who works in a school building should stop coming to work. every singl…
# hashtags : []
# ['rt', 'actually', 'something', 'every', 'person', 'work', 'school', 'building', 'stop', 'coming', 'work', 'every', 'singl']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# just keep it to yourself if its gonna hurt or break someone's heart. you might die a minute after you hurt someone… https://t.co/twpnm52xea
# hashtags : []
# ['keep', 'gon', 'na', 'hurt', 'break', 'someone', 'heart', 'might', 'die', 'minute', 'hurt', 'someone']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @schfinkes: i’m a texan. let me interpret for abbott, cruz, and cornyn: “thoughts &amp; prayers” = we love guns too much to care about these…
# hashtags : []
# ['rt', 'texan', 'let', 'interpret', 'abbott', 'cruz', 'cornyn', 'thought', 'amp', 'prayer', 'love', 'gun', 'much', 'care']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @samvimes6: looks like a normal business meeting to me... we always have that many bottles of wine around.
# #partygatephotos
# hashtags : ['#partygatephotos']
# ['rt', 'look', 'like', 'normal', 'business', 'meeting', 'always', 'many', 'bottle', 'wine', 'around', 'partygatephotos']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @zackbornstein: last week people picketed outside of a supreme court justice’s house, and the next day the senate unanimously passed a b…
# hashtags : []
# ['rt', 'last', 'week', 'people', 'picketed', 'outside', 'supreme', 'court', 'justice', 'house', 'next', 'day', 'senate', 'unanimously', 'passed', 'b']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @ndelriego: fourth-grade teacher eva mireles.
# she had worked for the uvalde school district for 17 years.
#
# she was reportedly shot and…
# hashtags : []
# ['rt', 'fourth', 'grade', 'teacher', 'eva', 'mireles', 'worked', 'uvalde', 'school', 'district', 'year', 'reportedly', 'shot']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @deathmetalv: i don't think a child's safety should have to take a backseat to someones sick fantasy of fighting government tyranny in a…
# hashtags : []
# ['rt', 'think', 'child', 'safety', 'take', 'backseat', 'someone', 'sick', 'fantasy', 'fighting', 'government', 'tyranny']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @esekino @melissa_galvans eso y el "yes i don't" o "there is a big reloj"son inolvidables
# hashtags : []
# ['galvans', 'eso', 'el', 'yes', 'big', 'reloj', 'son', 'inolvidables']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @tonytardio: i see kristina keneally has decided she no longer wants to live in the seat of fowler in sydney's southwest after failing t…
# hashtags : []
# ['rt', 'see', 'kristina', 'keneally', 'decided', 'longer', 'want', 'live', 'seat', 'fowler', 'sydney', 'southwest', 'failing']
# val : (0, 0, 1)   sentiments :  positive
#
#
# people who think like that aren't youth leaders. they're just campus politicians.
# hashtags : []
# ['people', 'think', 'like', 'youth', 'leader', 'campus', 'politician']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @um_ijt: if jamat e islami had been in the government of pakistan, the indian court would have responded to the bullying with the force…
# hashtags : []
# ['rt', 'ijt', 'jamat', 'e', 'islami', 'government', 'pakistan', 'indian', 'court', 'would', 'responded', 'bullying', 'force']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @hungdaddies: i learned to let guys take it as far as they can instead of forcing them to take the whole thing https://t.co/nkanif1q7y
# hashtags : []
# ['rt', 'learned', 'let', 'guy', 'take', 'far', 'instead', 'forcing', 'take', 'whole', 'thing']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @_l_e_xy1: hello everyone, please consider donating to my fundraiser. i’m transgender woman of color raising money for a top surgery #re…
# hashtags : ['#re']
# ['rt', 'l', 'e', 'xy', 'hello', 'everyone', 'please', 'consider', 'donating', 'fundraiser', 'transgender', 'woman', 'color', 'raising', 'money', 'top', 'surgery']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i really gotta go to the store and get cupcakes and take them to my baby school for his birthday on my lunch break… https://t.co/2jhawj7prr
# hashtags : []
# ['really', 'got', 'ta', 'go', 'store', 'get', 'cupcake', 'take', 'baby', 'school', 'birthday', 'lunch', 'break']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @lucyy31 @jamiecsergeant @khyrich @matthewsperrin so very well deserved, lucy. massive well done. it has been a ple… https://t.co/fpzrbjbeka
# hashtags : []
# ['well', 'deserved', 'lucy', 'massive', 'well', 'done', 'ple']
# val : (0, 0, 1)   sentiments :  positive
#
#
# next time don't love a woman if you just embarrass her.
# hashtags : []
# ['next', 'time', 'love', 'woman', 'embarrass']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @chayes_24 hunter try to threaten me with this shit 😂 i said please make me a stay home dad. 😂
# hashtags : []
# ['hunter', 'try', 'threaten', 'shit', 'said', 'please', 'make', 'stay', 'home', 'dad']
# val : (1, 0, 0)   sentiments :  negative
#
#
# loved ke huy quan. data and short round, my favorite characters in movies as a kid. you are an icon sir and you have another iconic role.
# hashtags : []
# ['loved', 'ke', 'huy', 'quan', 'data', 'short', 'round', 'favorite', 'character', 'movie', 'kid', 'icon', 'sir', 'another', 'iconic', 'role']
# val : (0, 0, 1)   sentiments :  positive
#
#
# #xrp #xrpcommunity #xrparmy #xrpholders $xrp #xrpsec
# #xrpthestandard.. see news below
#
# for latest news from xrp wor… https://t.co/e2rfa4zyqp
# hashtags : ['#xrp', '#xrpcommunity', '#xrparmy', '#xrpholders', '#xrpsec', '#xrpthestandard']
# ['xrp', 'xrpcommunity', 'xrparmy', 'xrpholders', 'xrp', 'xrpsec', 'xrpthestandard', 'see', 'news', 'latest', 'news', 'xrp', 'wor']
# val : (0, 0, 1)   sentiments :  positive
#
#
# @guardpilot @janevskialex @michaelianblack please have a seat because you never paid attention in school. why don't… https://t.co/kdjshw8ncp
# hashtags : []
# ['please', 'seat', 'never', 'paid', 'attention', 'school']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# @xianzhouren man i didn't need to see this because this aesthetic is 😘👌genshin pleaaaase
# hashtags : []
# ['man', 'need', 'see', 'aesthetic', 'genshin', 'pleaaaase']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @dashdobrofsky: i have a message for all of my young democrats in texas. take your anger, sadness, and rage…and use it to make sure beto…
# hashtags : []
# ['rt', 'message', 'young', 'democrat', 'texas', 'take', 'anger', 'sadness', 'rage', 'use', 'make', 'sure', 'beto']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @legalpornofan: @sarabeloff1c1al «Шмaра» is a word in russian that is perfect for you! remember it 😁😅😉 https://t.co/jqebzojprv
# hashtags : []
# ['rt', 'word', 'russian', 'perfect', 'remember']
# val : (0, 0, 1)   sentiments :  positive
# rt @asad_umar: kissing the flag i love https://t.co/jv0tdy8gqq
# hashtags : []
# ['rt', 'umar', 'kissing', 'flag', 'love']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @momokpopshop: 🏆giveaway🏆
#  —2nd win celebration—
#
# 🎁
# 2 d.t.s.r album
# 2 pob pc
#
# ✔️ina only
# ✔️close: 26/05 - 12:00
#
# ✔️rules:
# • rt &amp; likes…
# hashtags : []
# ['rt', 'giveaway', 'nd', 'win', 'celebration', 'r', 'album', 'pob', 'pc', 'ina', 'close', 'rule', 'rt', 'amp', 'like']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @fabrizioromano: espanyol are closing on portuguese fullback zé macedo from fc porto. free transfer set to be completed, he's born in 20…
# hashtags : []
# ['rt', 'espanyol', 'closing', 'portuguese', 'fullback', 'z', 'macedo', 'fc', 'porto', 'free', 'transfer', 'set', 'completed', 'born']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @loeytaro: here's a thread of missing children from robb elementary school in texas
#
# if you see this thread you're obligated to retweet…
# hashtags : []
# ['rt', 'thread', 'missing', 'child', 'robb', 'elementary', 'school', 'texas', 'see', 'thread', 'obligated', 'retweet']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# i be this made all you little cucks twitch
#
# send £20.00 if it did 👏🏻🥵
#
# findom femdom paypiguk finsubuk whalesub go… https://t.co/s6978a8k7f
# hashtags : []
# ['made', 'little', 'cucks', 'twitch', 'send', 'findom', 'femdom', 'paypiguk', 'finsubuk', 'whalesub', 'go']
# val : (1, 0, 0)   sentiments :  negative
#
#
# rt @atienoker: it's a gain time! kenya kwanza and william ruto's supporters, drop your handles. follow me, and i will follow back. like thi…
# hashtags : []
# ['rt', 'gain', 'time', 'kenya', 'kwanza', 'william', 'ruto', 'supporter', 'drop', 'handle', 'follow', 'follow', 'back', 'like', 'thi']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @stellvocals: i love him to death https://t.co/nnalypoyzx
# hashtags : []
# ['rt', 'love', 'death']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @randpaul: “as part of this plan, the who has contracted deutsche telekom to develop a global vaxx passport system, with plans to link e…
# hashtags : []
# ['rt', 'part', 'plan', 'contracted', 'deutsche', 'telekom', 'develop', 'global', 'vaxx', 'passport', 'system', 'plan', 'link', 'e']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @heliumwol: shinee as a group is now as old as taemin was when shinee debuted so
# hashtags : []
# ['rt', 'shinee', 'group', 'old', 'taemin', 'shinee', 'debuted']
# val : (0, 0, 1)   sentiments :  positive
#
#
# i can't handle this i can't handle this i can't handle this i can't handle this
# hashtags : []
# ['handle', 'handle', 'handle', 'handle']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# rt @hf_dreamcatcher: [🌑] in new york ✨ thank you @spotify @spotifykr @spotifykpop
#
# we’re honored to be a part of spotifyequal dreamcatcher…
# hashtags : []
# ['rt', 'dreamcatcher', 'new', 'york', 'thank', 'honored', 'part', 'spotifyequal', 'dreamcatcher']
# val : (1, 0, 0)   sentiments :  negative
#
#
# @jiswitty @rebeccamccoyb1 @liveonmbc @anayelinews @rexchapman if anti-abortion protesters can use pictures of a fet… https://t.co/7gnweipnwx
# hashtags : []
# ['anti', 'abortion', 'protester', 'use', 'picture', 'fet']
# val : (0, 1, 0)   sentiments :  neutral
#
#
# she must of been so overwhelmed for joy, but i am not exited for whats to come #bbau
# hashtags : ['#bbau']
# ['must', 'overwhelmed', 'joy', 'exited', 'whats', 'come', 'bbau']
# val : (0, 0, 1)   sentiments :  positive
#
#
# rt @weversetrsr: [treasure weverse] 20220525
# #yoshi post 🌟
#
# 🐯: when i got home hyunsuk hyung gave me a surprise gift. ahh i love it, its th…
# hashtags : ['#yoshi']
# ['rt', 'treasure', 'weverse', 'yoshi', 'post', 'got', 'home', 'hyunsuk', 'hyung', 'gave', 'surprise', 'gift', 'ahh', 'love', 'th']
# val : (1, 0, 0)   sentiments :  negative
#
#
#
#
# rt @mistresshicks: let me give you a drink daddy🥛 https://t.co/6wyvlf83t7
# hashtags : []
# ['rt', 'let', 'give', 'drink', 'daddy']
# val : (0, 1, 0)   sentiments :  neutral
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 for msg in consumer:
#       2         #print(str(1));
#       3         time.sleep(2)
#       5         data= text_lowercase(msg.value)
#
# File ~\anaconda3\lib\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\anaconda3\lib\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\anaconda3\lib\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\anaconda3\lib\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\anaconda3\lib\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\anaconda3\lib\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\anaconda3\lib\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~\anaconda3\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\anaconda3\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
